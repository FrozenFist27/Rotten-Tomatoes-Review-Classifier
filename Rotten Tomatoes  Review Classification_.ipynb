# %%
import pandas as pd
import numpy as np
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import re

# %%
data = pd.read_csv('train.tsv', sep = '\t')
data.head(10)
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1         2           1  A series of escapades demonstrating the adage ...
# 2         3           1                                           A series
# 3         4           1                                                  A
# 4         5           1                                             series
# 5         6           1  of escapades demonstrating the adage that what...
# 6         7           1                                                 of
# 7         8           1  escapades demonstrating the adage that what is...
# 8         9           1                                          escapades
# 9        10           1  demonstrating the adage that what is good for ...
#
#    Sentiment
# 0          1
# 1          2
# 2          2
# 3          2
# 4          2
# 5          2
# 6          2
# 7          2
# 8          2
# 9          2

# %%
import sklearn
print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# The scikit-learn version is 0.21.2.

# %%
data['Sentiment'].value_counts()
# Out:
# 2    79582
# 3    32927
# 1    27273
# 4     9206
# 0     7072
# Name: Sentiment, dtype: int64

# %%
lemma = WordNetLemmatizer()

# %%
def clean_data(data_column):
    revised_data = []
    for i in range(0,len(data_column)):
        review = str(data_column[i])
        review = re.sub('[^a-zA-Z]',' ', review)
        review = [lemma.lemmatize(y) for y in word_tokenize(review.lower())]
        review = ' '.join(review)
        revised_data.append(review)
    return revised_data

# %%
data['Revised_Phrase'] = clean_data(data.Phrase.values)
data.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1         2           1  A series of escapades demonstrating the adage ...
# 2         3           1                                           A series
# 3         4           1                                                  A
# 4         5           1                                             series
#
#    Sentiment                                     Revised_Phrase
# 0          1  a series of escapade demonstrating the adage t...
# 1          2  a series of escapade demonstrating the adage t...
# 2          2                                           a series
# 3          2                                                  a
# 4          2                                             series

# %%
from sklearn.utils import resample

# %%
data_1 = data[data['Sentiment'] == 1]
data_2 = data[data['Sentiment'] == 2]
data_3 = data[data['Sentiment'] == 3]
data_4 = data[data['Sentiment'] == 4]
data_5 = data[data['Sentiment'] == 0]

data_1_sample = resample(data_1, replace = True ,n_samples = 75000,
                        random_state = 123)
data_2_sample = resample(data_2, replace = True ,n_samples = 75000,
                        random_state = 123)
data_3_sample = resample(data_3, replace = True ,n_samples = 75000,
                        random_state = 123)
data_4_sample = resample(data_4, replace = True ,n_samples = 75000,
                        random_state = 123)
data_5_sample = resample(data_5, replace = True ,n_samples = 75000,
                        random_state = 123)

data_resampled = pd.concat([data_1, data_1_sample, data_2,
                               data_2_sample, data_3,
                               data_3_sample, data_4,
                               data_4_sample, data_5,
                               data_5_sample])

# %%
data_resampled.head()
# Out:
#     PhraseId  SentenceId                                             Phrase  \
# 0          1           1  A series of escapades demonstrating the adage ...
# 33        34           1  the gander , some of which occasionally amuses...
# 47        48           1       but none of which amounts to much of a story
# 49        50           1           none of which amounts to much of a story
# 81        82           3  Even fans of Ismail Merchant 's work , I suspe...
#
#     Sentiment                                     Revised_Phrase
# 0           1  a series of escapade demonstrating the adage t...
# 33          1  the gander some of which occasionally amuses b...
# 47          1        but none of which amount to much of a story
# 49          1            none of which amount to much of a story
# 81          1  even fan of ismail merchant s work i suspect w...

# %%
from nltk.util import ngrams
from nltk.tokenize import TweetTokenizer
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
text = ' '.join(data_resampled.loc[data_resampled.Sentiment == 4,
                                  'Phrase'].values)
text_trigrams = [i for i in ngrams(text.split(), 3)]
text_trigrams
# Out:
# [('This', 'quiet', ','),
#  ('quiet', ',', 'introspective'),
#  (',', 'introspective', 'and'),
#  ('introspective', 'and', 'entertaining'),
#  ('and', 'entertaining', 'independent'),
#  ('entertaining', 'independent', 'is'),
#  ('independent', 'is', 'worth'),
#  ('is', 'worth', 'seeking'),
#  ('worth', 'seeking', '.'),
#  ('seeking', '.', 'quiet'),
#  ('.', 'quiet', ','),
#  ('quiet', ',', 'introspective'),
#  (',', 'introspective', 'and'),
#  ('introspective', 'and', 'entertaining'),
#  ('and', 'entertaining', 'independent'),
#  ('entertaining', 'independent', 'entertaining'),
#  ('independent', 'entertaining', 'is'),
#  ('entertaining', 'is', 'worth'),
#  ('is', 'worth', 'seeking'),
#  ('worth', 'seeking', 'A'),
#  ('seeking', 'A', 'positively'),
#  ('A', 'positively', 'thrilling'),
#  ('positively', 'thrilling', 'combination'),
#  ('thrilling', 'combination', 'of'),
#  ('combination', 'of', 'ethnography'),
#  ('of', 'ethnography', 'and'),
#  ('ethnography', 'and', 'all'),
#  ('and', 'all', 'the'),
#  ('all', 'the', 'intrigue'),
#  ('the', 'intrigue', ','),
#  ('intrigue', ',', 'betrayal'),
#  (',', 'betrayal', ','),
#  ('betrayal', ',', 'deceit'),
#  (',', 'deceit', 'and'),
#  ('deceit', 'and', 'murder'),
#  ('and', 'murder', 'of'),
#  ('murder', 'of', 'a'),
#  ('of', 'a', 'Shakespearean'),
#  ('a', 'Shakespearean', 'tragedy'),
#  ('Shakespearean', 'tragedy', 'or'),
#  ('tragedy', 'or', 'a'),
#  ('or', 'a', 'juicy'),
#  ('a', 'juicy', 'soap'),
#  ('juicy', 'soap', 'opera'),
#  ('soap', 'opera', 'A'),
#  ('opera', 'A', 'positively'),
#  ('A', 'positively', 'thrilling'),
#  ('positively', 'thrilling', 'combination'),
#  ('thrilling', 'combination', 'of'),
#  ('combination', 'of', 'ethnography'),
#  ('of', 'ethnography', 'and'),
#  ('ethnography', 'and', 'all'),
#  ('and', 'all', 'the'),
#  ('all', 'the', 'intrigue'),
#  ('the', 'intrigue', ','),
#  ('intrigue', ',', 'betrayal'),
#  (',', 'betrayal', ','),
#  ('betrayal', ',', 'deceit'),
#  (',', 'deceit', 'and'),
#  ('deceit', 'and', 'murder'),
#  ('and', 'murder', 'thrilling'),
#  ('murder', 'thrilling', 'A'),
#  ('thrilling', 'A', 'comedy-drama'),
#  ('A', 'comedy-drama', 'of'),
#  ('comedy-drama', 'of', 'nearly'),
#  ('of', 'nearly', 'epic'),
#  ('nearly', 'epic', 'proportions'),
#  ('epic', 'proportions', 'rooted'),
#  ('proportions', 'rooted', 'in'),
#  ('rooted', 'in', 'a'),
#  ('in', 'a', 'sincere'),
#  ('a', 'sincere', 'performance'),
#  ('sincere', 'performance', 'by'),
#  ('performance', 'by', 'the'),
#  ('by', 'the', 'title'),
#  ('the', 'title', 'character'),
#  ('title', 'character', 'undergoing'),
#  ('character', 'undergoing', 'midlife'),
#  ('undergoing', 'midlife', 'crisis'),
#  ('midlife', 'crisis', '.'),
#  ('crisis', '.', 'nearly'),
#  ('.', 'nearly', 'epic'),
#  ('nearly', 'epic', 'rooted'),
#  ('epic', 'rooted', 'in'),
#  ('rooted', 'in', 'a'),
#  ('in', 'a', 'sincere'),
#  ('a', 'sincere', 'performance'),
#  ('sincere', 'performance', 'by'),
#  ('performance', 'by', 'the'),
#  ('by', 'the', 'title'),
#  ('the', 'title', 'character'),
#  ('title', 'character', 'undergoing'),
#  ('character', 'undergoing', 'midlife'),
#  ('undergoing', 'midlife', 'crisis'),
#  ('midlife', 'crisis', '.'),
#  ('crisis', '.', 'in'),
#  ('.', 'in', 'a'),
#  ('in', 'a', 'sincere'),
#  ('a', 'sincere', 'performance'),
#  ('sincere', 'performance', 'a'),
#  ('performance', 'a', 'sincere'),
#  ('a', 'sincere', 'performance'),
#  ('sincere', 'performance', 'sincere'),
#  ('performance', 'sincere', 'performance'),
#  ('sincere', 'performance', 'recommend'),
#  ('performance', 'recommend', 'Snow'),
#  ('recommend', 'Snow', 'Dogs'),
#  ('Snow', 'Dogs', 'high'),
#  ('Dogs', 'high', 'hilarity'),
#  ('high', 'hilarity', 'The'),
#  ('hilarity', 'The', 'performances'),
#  ('The', 'performances', 'are'),
#  ('performances', 'are', 'an'),
#  ('are', 'an', 'absolute'),
#  ('an', 'absolute', 'joy'),
#  ('absolute', 'joy', '.'),
#  ('joy', '.', 'are'),
#  ('.', 'are', 'an'),
#  ('are', 'an', 'absolute'),
#  ('an', 'absolute', 'joy'),
#  ('absolute', 'joy', '.'),
#  ('joy', '.', 'an'),
#  ('.', 'an', 'absolute'),
#  ('an', 'absolute', 'joy'),
#  ('absolute', 'joy', 'joy'),
#  ('joy', 'joy', 'extravagant'),
#  ('joy', 'extravagant', 'better'),
#  ('extravagant', 'better', 'this'),
#  ('better', 'this', 'one'),
#  ('this', 'one', 'is'),
#  ('one', 'is', 'a'),
#  ('is', 'a', 'sweet'),
#  ('a', 'sweet', 'and'),
#  ('sweet', 'and', 'modest'),
#  ('and', 'modest', 'and'),
#  ('modest', 'and', 'ultimately'),
#  ('and', 'ultimately', 'winning'),
#  ('ultimately', 'winning', 'story'),
#  ('winning', 'story', '.'),
#  ('story', '.', 'is'),
#  ('.', 'is', 'a'),
#  ('is', 'a', 'sweet'),
#  ('a', 'sweet', 'and'),
#  ('sweet', 'and', 'modest'),
#  ('and', 'modest', 'and'),
#  ('modest', 'and', 'ultimately'),
#  ('and', 'ultimately', 'winning'),
#  ('ultimately', 'winning', 'story'),
#  ('winning', 'story', '.'),
#  ('story', '.', 'a'),
#  ('.', 'a', 'sweet'),
#  ('a', 'sweet', 'and'),
#  ('sweet', 'and', 'modest'),
#  ('and', 'modest', 'sweet'),
#  ('modest', 'sweet', 'ultimately'),
#  ('sweet', 'ultimately', 'winning'),
#  ('ultimately', 'winning', 'story'),
#  ('winning', 'story', 'dizzily'),
#  ('story', 'dizzily', 'gorgeous'),
#  ('dizzily', 'gorgeous', 'Love'),
#  ('gorgeous', 'Love', '--'),
#  ('Love', '--', 'very'),
#  ('--', 'very', 'much'),
#  ('very', 'much', 'Love'),
#  ('much', 'Love', 'Best'),
#  ('Love', 'Best', 'indie'),
#  ('Best', 'indie', 'of'),
#  ('indie', 'of', 'the'),
#  ('of', 'the', 'year'),
#  ('the', 'year', ','),
#  ('year', ',', 'so'),
#  (',', 'so', 'far'),
#  ('so', 'far', '.'),
#  ('far', '.', 'Best'),
#  ('.', 'Best', 'indie'),
#  ('Best', 'indie', 'of'),
#  ('indie', 'of', 'the'),
#  ('of', 'the', 'year'),
#  ('the', 'year', ','),
#  ('year', ',', 'so'),
#  (',', 'so', 'far'),
#  ('so', 'far', 'impeccable'),
#  ('far', 'impeccable', 'well-constructed'),
#  ('impeccable', 'well-constructed', 'narrative'),
#  ('well-constructed', 'narrative', 'the'),
#  ('narrative', 'the', 'first'),
#  ('the', 'first', 'computer-generated'),
#  ('first', 'computer-generated', 'feature'),
#  ('computer-generated', 'feature', 'cartoon'),
#  ('feature', 'cartoon', 'to'),
#  ('cartoon', 'to', 'feel'),
#  ('to', 'feel', 'like'),
#  ('feel', 'like', 'other'),
#  ('like', 'other', 'movies'),
#  ('other', 'movies', 'the'),
#  ('movies', 'the', 'runaway'),
#  ('the', 'runaway', 'success'),
#  ('runaway', 'success', 'of'),
#  ('success', 'of', 'his'),
#  ('of', 'his', 'first'),
#  ('his', 'first', 'film'),
#  ('first', 'film', ','),
#  ('film', ',', 'The'),
#  (',', 'The', 'Full'),
#  ('The', 'Full', 'Monty'),
#  ('Full', 'Monty', ','),
#  ('Monty', ',', 'the'),
#  (',', 'the', 'runaway'),
#  ('the', 'runaway', 'success'),
#  ('runaway', 'success', 'amusing'),
#  ('success', 'amusing', 'young'),
#  ('amusing', 'young', 'romantics'),
#  ('young', 'romantics', 'If'),
#  ('romantics', 'If', 'a'),
#  ('If', 'a', 'horror'),
#  ('a', 'horror', 'movie'),
#  ('horror', 'movie', "'s"),
#  ('movie', "'s", 'primary'),
#  ("'s", 'primary', 'goal'),
#  ('primary', 'goal', 'is'),
#  ('goal', 'is', 'to'),
#  ('is', 'to', 'frighten'),
#  ('to', 'frighten', 'and'),
#  ('frighten', 'and', 'disturb'),
#  ('and', 'disturb', ','),
#  ('disturb', ',', 'then'),
#  (',', 'then', 'They'),
#  ('then', 'They', 'works'),
#  ('They', 'works', 'spectacularly'),
#  ('works', 'spectacularly', 'well'),
#  ('spectacularly', 'well', '...'),
#  ('well', '...', 'A'),
#  ('...', 'A', 'shiver-inducing'),
#  ('A', 'shiver-inducing', ','),
#  ('shiver-inducing', ',', 'nerve-rattling'),
#  (',', 'nerve-rattling', 'ride'),
#  ('nerve-rattling', 'ride', '.'),
#  ('ride', '.', ','),
#  ('.', ',', 'then'),
#  (',', 'then', 'They'),
#  ('then', 'They', 'works'),
#  ('They', 'works', 'spectacularly'),
#  ('works', 'spectacularly', 'well'),
#  ('spectacularly', 'well', '...'),
#  ('well', '...', 'A'),
#  ('...', 'A', 'shiver-inducing'),
#  ('A', 'shiver-inducing', ','),
#  ('shiver-inducing', ',', 'nerve-rattling'),
#  (',', 'nerve-rattling', 'ride'),
#  ('nerve-rattling', 'ride', '.'),
#  ('ride', '.', 'then'),
#  ('.', 'then', 'They'),
#  ('then', 'They', 'works'),
#  ('They', 'works', 'spectacularly'),
#  ('works', 'spectacularly', 'well'),
#  ('spectacularly', 'well', '...'),
#  ('well', '...', 'A'),
#  ('...', 'A', 'shiver-inducing'),
#  ('A', 'shiver-inducing', ','),
#  ('shiver-inducing', ',', 'nerve-rattling'),
#  (',', 'nerve-rattling', 'ride'),
#  ('nerve-rattling', 'ride', '.'),
#  ('ride', '.', 'They'),
#  ('.', 'They', 'works'),
#  ('They', 'works', 'spectacularly'),
#  ('works', 'spectacularly', 'well'),
#  ('spectacularly', 'well', '...'),
#  ('well', '...', 'A'),
#  ('...', 'A', 'shiver-inducing'),
#  ('A', 'shiver-inducing', ','),
#  ('shiver-inducing', ',', 'nerve-rattling'),
#  (',', 'nerve-rattling', 'ride'),
#  ('nerve-rattling', 'ride', '.'),
#  ('ride', '.', 'works'),
#  ('.', 'works', 'spectacularly'),
#  ('works', 'spectacularly', 'well'),
#  ('spectacularly', 'well', '...'),
#  ('well', '...', 'A'),
#  ('...', 'A', 'shiver-inducing'),
#  ('A', 'shiver-inducing', ','),
#  ('shiver-inducing', ',', 'nerve-rattling'),
#  (',', 'nerve-rattling', 'ride'),
#  ('nerve-rattling', 'ride', '.'),
#  ('ride', '.', 'works'),
#  ('.', 'works', 'spectacularly'),
#  ('works', 'spectacularly', 'well'),
#  ('spectacularly', 'well', '...'),
#  ('well', '...', 'A'),
#  ('...', 'A', 'shiver-inducing'),
#  ('A', 'shiver-inducing', ','),
#  ('shiver-inducing', ',', 'nerve-rattling'),
#  (',', 'nerve-rattling', 'ride'),
#  ('nerve-rattling', 'ride', 'spectacularly'),
#  ('ride', 'spectacularly', 'well'),
#  ('spectacularly', 'well', 'spectacularly'),
#  ('well', 'spectacularly', 'the'),
#  ('spectacularly', 'the', 'sensational'),
#  ('the', 'sensational', 'true-crime'),
#  ('sensational', 'true-crime', 'hell-jaunt'),
#  ('true-crime', 'hell-jaunt', 'purists'),
#  ('hell-jaunt', 'purists', 'might'),
#  ('purists', 'might', 'like'),
#  ('might', 'like', 'and'),
#  ('like', 'and', 'more'),
#  ('and', 'more', 'experimental'),
#  ('more', 'experimental', 'in'),
#  ('experimental', 'in', 'its'),
#  ('in', 'its', 'storytelling'),
#  ('its', 'storytelling', '-LRB-'),
#  ('storytelling', '-LRB-', 'though'),
#  ('-LRB-', 'though', 'no'),
#  ('though', 'no', 'less'),
#  ('no', 'less', 'horrifying'),
#  ('less', 'horrifying', 'for'),
#  ('horrifying', 'for', 'it'),
#  ('for', 'it', '-RRB-'),
#  ('it', '-RRB-', 'sensational'),
#  ('-RRB-', 'sensational', 'true-crime'),
#  ('sensational', 'true-crime', 'sensational'),
#  ('true-crime', 'sensational', 'satisfying'),
#  ('sensational', 'satisfying', 'Jones'),
#  ('satisfying', 'Jones', 'has'),
#  ('Jones', 'has', 'tackled'),
#  ('has', 'tackled', 'a'),
#  ('tackled', 'a', 'meaty'),
#  ('a', 'meaty', 'subject'),
#  ('meaty', 'subject', 'and'),
#  ('subject', 'and', 'drawn'),
#  ('and', 'drawn', 'engaging'),
#  ('drawn', 'engaging', 'characters'),
#  ('engaging', 'characters', 'while'),
#  ('characters', 'while', 'peppering'),
#  ('while', 'peppering', 'the'),
#  ('peppering', 'the', 'pages'),
#  ('the', 'pages', 'with'),
#  ('pages', 'with', 'memorable'),
#  ('with', 'memorable', 'zingers'),
#  ('memorable', 'zingers', '.'),
#  ('zingers', '.', 'has'),
#  ('.', 'has', 'tackled'),
#  ('has', 'tackled', 'a'),
#  ('tackled', 'a', 'meaty'),
#  ('a', 'meaty', 'subject'),
#  ('meaty', 'subject', 'and'),
#  ('subject', 'and', 'drawn'),
#  ('and', 'drawn', 'engaging'),
#  ('drawn', 'engaging', 'characters'),
#  ('engaging', 'characters', 'while'),
#  ('characters', 'while', 'peppering'),
#  ('while', 'peppering', 'the'),
#  ('peppering', 'the', 'pages'),
#  ('the', 'pages', 'with'),
#  ('pages', 'with', 'memorable'),
#  ('with', 'memorable', 'zingers'),
#  ('memorable', 'zingers', '.'),
#  ('zingers', '.', 'tackled'),
#  ('.', 'tackled', 'a'),
#  ('tackled', 'a', 'meaty'),
#  ('a', 'meaty', 'subject'),
#  ('meaty', 'subject', 'and'),
#  ('subject', 'and', 'drawn'),
#  ('and', 'drawn', 'engaging'),
#  ('drawn', 'engaging', 'characters'),
#  ('engaging', 'characters', 'while'),
#  ('characters', 'while', 'peppering'),
#  ('while', 'peppering', 'the'),
#  ('peppering', 'the', 'pages'),
#  ('the', 'pages', 'with'),
#  ('pages', 'with', 'memorable'),
#  ('with', 'memorable', 'zingers'),
#  ('memorable', 'zingers', 'drawn'),
#  ('zingers', 'drawn', 'engaging'),
#  ('drawn', 'engaging', 'characters'),
#  ('engaging', 'characters', 'engaging'),
#  ('characters', 'engaging', 'memorable'),
#  ('engaging', 'memorable', 'Bloody'),
#  ('memorable', 'Bloody', 'Sunday'),
#  ('Bloody', 'Sunday', 'has'),
#  ('Sunday', 'has', 'the'),
#  ('has', 'the', 'grace'),
#  ('the', 'grace', 'to'),
#  ('grace', 'to', 'call'),
#  ('to', 'call', 'for'),
#  ('call', 'for', 'prevention'),
#  ('for', 'prevention', 'rather'),
#  ('prevention', 'rather', 'than'),
#  ('rather', 'than', 'to'),
#  ('than', 'to', 'place'),
#  ('to', 'place', 'blame'),
#  ('place', 'blame', ','),
#  ('blame', ',', 'making'),
#  (',', 'making', 'it'),
#  ('making', 'it', 'one'),
#  ('it', 'one', 'of'),
#  ('one', 'of', 'the'),
#  ('of', 'the', 'best'),
#  ('the', 'best', 'war'),
#  ('best', 'war', 'movies'),
#  ('war', 'movies', 'ever'),
#  ('movies', 'ever', 'made'),
#  ('ever', 'made', '.'),
#  ('made', '.', 'has'),
#  ('.', 'has', 'the'),
#  ('has', 'the', 'grace'),
#  ('the', 'grace', 'to'),
#  ('grace', 'to', 'call'),
#  ('to', 'call', 'for'),
#  ('call', 'for', 'prevention'),
#  ('for', 'prevention', 'rather'),
#  ('prevention', 'rather', 'than'),
#  ('rather', 'than', 'to'),
#  ('than', 'to', 'place'),
#  ('to', 'place', 'blame'),
#  ('place', 'blame', ','),
#  ('blame', ',', 'making'),
#  (',', 'making', 'it'),
#  ('making', 'it', 'one'),
#  ('it', 'one', 'of'),
#  ('one', 'of', 'the'),
#  ('of', 'the', 'best'),
#  ('the', 'best', 'war'),
#  ('best', 'war', 'movies'),
#  ('war', 'movies', 'ever'),
#  ('movies', 'ever', 'made'),
#  ('ever', 'made', '.'),
#  ('made', '.', 'has'),
#  ('.', 'has', 'the'),
#  ('has', 'the', 'grace'),
#  ('the', 'grace', 'to'),
#  ('grace', 'to', 'call'),
#  ('to', 'call', 'for'),
#  ('call', 'for', 'prevention'),
#  ('for', 'prevention', 'rather'),
#  ('prevention', 'rather', 'than'),
#  ('rather', 'than', 'to'),
#  ('than', 'to', 'place'),
#  ('to', 'place', 'blame'),
#  ('place', 'blame', ','),
#  ('blame', ',', 'making'),
#  (',', 'making', 'it'),
#  ('making', 'it', 'one'),
#  ('it', 'one', 'of'),
#  ('one', 'of', 'the'),
#  ('of', 'the', 'best'),
#  ('the', 'best', 'war'),
#  ('best', 'war', 'movies'),
#  ('war', 'movies', 'ever'),
#  ('movies', 'ever', 'made'),
#  ('ever', 'made', 'the'),
#  ('made', 'the', 'grace'),
#  ('the', 'grace', 'to'),
#  ('grace', 'to', 'call'),
#  ('to', 'call', 'for'),
#  ('call', 'for', 'prevention'),
#  ('for', 'prevention', 'rather'),
#  ('prevention', 'rather', 'than'),
#  ('rather', 'than', 'to'),
#  ('than', 'to', 'place'),
#  ('to', 'place', 'blame'),
#  ('place', 'blame', ','),
#  ('blame', ',', 'making'),
#  (',', 'making', 'it'),
#  ('making', 'it', 'one'),
#  ('it', 'one', 'of'),
#  ('one', 'of', 'the'),
#  ('of', 'the', 'best'),
#  ('the', 'best', 'war'),
#  ('best', 'war', 'movies'),
#  ('war', 'movies', 'ever'),
#  ('movies', 'ever', 'made'),
#  ('ever', 'made', 'grace'),
#  ('made', 'grace', 'to'),
#  ('grace', 'to', 'call'),
#  ('to', 'call', 'for'),
#  ('call', 'for', 'prevention'),
#  ('for', 'prevention', 'rather'),
#  ('prevention', 'rather', 'than'),
#  ('rather', 'than', 'to'),
#  ('than', 'to', 'place'),
#  ('to', 'place', 'blame'),
#  ('place', 'blame', ','),
#  ('blame', ',', 'making'),
#  (',', 'making', 'it'),
#  ('making', 'it', 'one'),
#  ('it', 'one', 'of'),
#  ('one', 'of', 'the'),
#  ('of', 'the', 'best'),
#  ('the', 'best', 'war'),
#  ('best', 'war', 'movies'),
#  ('war', 'movies', 'ever'),
#  ('movies', 'ever', 'made'),
#  ('ever', 'made', 'to'),
#  ('made', 'to', 'call'),
#  ('to', 'call', 'for'),
#  ('call', 'for', 'prevention'),
#  ('for', 'prevention', 'rather'),
#  ('prevention', 'rather', 'than'),
#  ('rather', 'than', 'to'),
#  ('than', 'to', 'place'),
#  ('to', 'place', 'blame'),
#  ('place', 'blame', ','),
#  ('blame', ',', 'making'),
#  (',', 'making', 'it'),
#  ('making', 'it', 'one'),
#  ('it', 'one', 'of'),
#  ('one', 'of', 'the'),
#  ('of', 'the', 'best'),
#  ('the', 'best', 'war'),
#  ('best', 'war', 'movies'),
#  ('war', 'movies', 'ever'),
#  ('movies', 'ever', 'made'),
#  ('ever', 'made', 'call'),
#  ('made', 'call', 'for'),
#  ('call', 'for', 'prevention'),
#  ('for', 'prevention', 'rather'),
#  ('prevention', 'rather', 'than'),
#  ('rather', 'than', 'to'),
#  ('than', 'to', 'place'),
#  ('to', 'place', 'blame'),
#  ('place', 'blame', ','),
#  ('blame', ',', 'making'),
#  (',', 'making', 'it'),
#  ('making', 'it', 'one'),
#  ('it', 'one', 'of'),
#  ('one', 'of', 'the'),
#  ('of', 'the', 'best'),
#  ('the', 'best', 'war'),
#  ('best', 'war', 'movies'),
#  ('war', 'movies', 'ever'),
#  ('movies', 'ever', 'made'),
#  ('ever', 'made', 'making'),
#  ('made', 'making', 'it'),
#  ('making', 'it', 'one'),
#  ('it', 'one', 'of'),
#  ('one', 'of', 'the'),
#  ('of', 'the', 'best'),
#  ('the', 'best', 'war'),
#  ('best', 'war', 'movies'),
#  ('war', 'movies', 'ever'),
#  ('movies', 'ever', 'made'),
#  ('ever', 'made', 'it'),
#  ('made', 'it', 'one'),
#  ('it', 'one', 'of'),
#  ('one', 'of', 'the'),
#  ('of', 'the', 'best'),
#  ('the', 'best', 'war'),
#  ('best', 'war', 'movies'),
#  ('war', 'movies', 'ever'),
#  ('movies', 'ever', 'made'),
#  ('ever', 'made', 'one'),
#  ('made', 'one', 'of'),
#  ('one', 'of', 'the'),
#  ('of', 'the', 'best'),
#  ('the', 'best', 'war'),
#  ('best', 'war', 'movies'),
#  ('war', 'movies', 'ever'),
#  ('movies', 'ever', 'made'),
#  ('ever', 'made', 'of'),
#  ('made', 'of', 'the'),
#  ('of', 'the', 'best'),
#  ('the', 'best', 'war'),
#  ('best', 'war', 'movies'),
#  ('war', 'movies', 'ever'),
#  ('movies', 'ever', 'made'),
#  ('ever', 'made', 'the'),
#  ('made', 'the', 'best'),
#  ('the', 'best', 'war'),
#  ('best', 'war', 'movies'),
#  ('war', 'movies', 'ever'),
#  ('movies', 'ever', 'made'),
#  ('ever', 'made', 'best'),
#  ('made', 'best', 'war'),
#  ('best', 'war', 'movies'),
#  ('war', 'movies', 'Perhaps'),
#  ('movies', 'Perhaps', 'it'),
#  ('Perhaps', 'it', "'s"),
#  ('it', "'s", 'cliche'),
#  ("'s", 'cliche', 'to'),
#  ('cliche', 'to', 'call'),
#  ('to', 'call', 'the'),
#  ('call', 'the', 'film'),
#  ('the', 'film', '`'),
#  ('film', '`', 'refreshing'),
#  ('`', 'refreshing', ','),
#  ('refreshing', ',', "'"),
#  (',', "'", 'but'),
#  ("'", 'but', 'it'),
#  ('but', 'it', 'is'),
#  ('it', 'is', '.'),
#  ('is', '.', 'Perhaps'),
#  ('.', 'Perhaps', 'it'),
#  ('Perhaps', 'it', "'s"),
#  ('it', "'s", 'cliche'),
#  ("'s", 'cliche', 'to'),
#  ('cliche', 'to', 'call'),
#  ('to', 'call', 'the'),
#  ('call', 'the', 'film'),
#  ('the', 'film', '`'),
#  ('film', '`', 'refreshing'),
#  ('`', 'refreshing', ','),
#  ('refreshing', ',', "'"),
#  (',', "'", 'but'),
#  ("'", 'but', 'it'),
#  ('but', 'it', 'is'),
#  ('it', 'is', '`'),
#  ('is', '`', 'refreshing'),
#  ('`', 'refreshing', 'Both'),
#  ('refreshing', 'Both', 'lead'),
#  ('Both', 'lead', 'performances'),
#  ('lead', 'performances', 'are'),
#  ('performances', 'are', 'Oscar-size'),
#  ('are', 'Oscar-size', '.'),
#  ('Oscar-size', '.', 'a'),
#  ('.', 'a', 'smart'),
#  ('a', 'smart', 'new'),
#  ('smart', 'new', 'comedy'),
#  ('new', 'comedy', 'smart'),
#  ('comedy', 'smart', 'new'),
#  ('smart', 'new', 'comedy'),
#  ('new', 'comedy', 'smart'),
#  ('comedy', 'smart', 'impressed'),
#  ('smart', 'impressed', 'good'),
#  ('impressed', 'good', 'fun'),
#  ('good', 'fun', 'fun'),
#  ('fun', 'fun', 'A'),
#  ('fun', 'A', 'smart'),
#  ('A', 'smart', ','),
#  ('smart', ',', 'provocative'),
#  (',', 'provocative', 'drama'),
#  ('provocative', 'drama', 'that'),
#  ('drama', 'that', 'does'),
#  ('that', 'does', 'the'),
#  ('does', 'the', 'nearly'),
#  ('the', 'nearly', 'impossible'),
#  ('nearly', 'impossible', ':'),
#  ('impossible', ':', 'It'),
#  (':', 'It', 'gets'),
#  ('It', 'gets', 'under'),
#  ('gets', 'under', 'the'),
#  ('under', 'the', 'skin'),
#  ('the', 'skin', 'of'),
#  ('skin', 'of', 'a'),
#  ('of', 'a', 'man'),
#  ('a', 'man', 'we'),
#  ('man', 'we', 'only'),
#  ('we', 'only', 'know'),
#  ('only', 'know', 'as'),
#  ('know', 'as', 'an'),
#  ('as', 'an', 'evil'),
#  ('an', 'evil', ','),
#  ('evil', ',', 'monstrous'),
#  (',', 'monstrous', 'lunatic'),
#  ('monstrous', 'lunatic', '.'),
#  ('lunatic', '.', 'A'),
#  ('.', 'A', 'smart'),
#  ('A', 'smart', ','),
#  ('smart', ',', 'provocative'),
#  (',', 'provocative', 'drama'),
#  ('provocative', 'drama', 'that'),
#  ('drama', 'that', 'does'),
#  ('that', 'does', 'the'),
#  ('does', 'the', 'nearly'),
#  ('the', 'nearly', 'impossible'),
#  ('nearly', 'impossible', ':'),
#  ('impossible', ':', 'It'),
#  (':', 'It', 'gets'),
#  ('It', 'gets', 'under'),
#  ('gets', 'under', 'the'),
#  ('under', 'the', 'skin'),
#  ('the', 'skin', 'of'),
#  ('skin', 'of', 'a'),
#  ('of', 'a', 'man'),
#  ('a', 'man', 'we'),
#  ('man', 'we', 'only'),
#  ('we', 'only', 'know'),
#  ('only', 'know', 'as'),
#  ('know', 'as', 'an'),
#  ('as', 'an', 'evil'),
#  ('an', 'evil', ','),
#  ('evil', ',', 'monstrous'),
#  (',', 'monstrous', 'lunatic'),
#  ('monstrous', 'lunatic', 'A'),
#  ('lunatic', 'A', 'smart'),
#  ('A', 'smart', ','),
#  ('smart', ',', 'provocative'),
#  (',', 'provocative', 'drama'),
#  ('provocative', 'drama', 'that'),
#  ('drama', 'that', 'does'),
#  ('that', 'does', 'the'),
#  ('does', 'the', 'nearly'),
#  ('the', 'nearly', 'impossible'),
#  ('nearly', 'impossible', ':'),
#  ('impossible', ':', 'A'),
#  (':', 'A', 'smart'),
#  ('A', 'smart', ','),
#  ('smart', ',', 'provocative'),
#  (',', 'provocative', 'drama'),
#  ('provocative', 'drama', 'that'),
#  ('drama', 'that', 'does'),
#  ('that', 'does', 'the'),
#  ('does', 'the', 'nearly'),
#  ('the', 'nearly', 'impossible'),
#  ('nearly', 'impossible', 'smart'),
#  ('impossible', 'smart', ','),
#  ('smart', ',', 'provocative'),
#  (',', 'provocative', 'drama'),
#  ('provocative', 'drama', 'provocative'),
#  ('drama', 'provocative', 'drama'),
#  ('provocative', 'drama', 'does'),
#  ('drama', 'does', 'the'),
#  ('does', 'the', 'nearly'),
#  ('the', 'nearly', 'impossible'),
#  ('nearly', 'impossible', 'very'),
#  ('impossible', 'very', 'funny'),
#  ('very', 'funny', 'has'),
#  ('funny', 'has', 'made'),
#  ('has', 'made', 'a'),
#  ('made', 'a', 'movie'),
#  ('a', 'movie', 'that'),
#  ('movie', 'that', 'will'),
#  ('that', 'will', 'leave'),
#  ('will', 'leave', 'you'),
#  ('leave', 'you', 'wondering'),
#  ('you', 'wondering', 'about'),
#  ('wondering', 'about', 'the'),
#  ('about', 'the', 'characters'),
#  ('the', 'characters', "'"),
#  ('characters', "'", 'lives'),
#  ("'", 'lives', 'after'),
#  ('lives', 'after', 'the'),
#  ('after', 'the', 'clever'),
#  ('the', 'clever', 'credits'),
#  ('clever', 'credits', 'roll'),
#  ('credits', 'roll', 'made'),
#  ('roll', 'made', 'a'),
#  ('made', 'a', 'movie'),
#  ('a', 'movie', 'that'),
#  ('movie', 'that', 'will'),
#  ('that', 'will', 'leave'),
#  ('will', 'leave', 'you'),
#  ('leave', 'you', 'wondering'),
#  ('you', 'wondering', 'about'),
#  ('wondering', 'about', 'the'),
#  ('about', 'the', 'characters'),
#  ('the', 'characters', "'"),
#  ('characters', "'", 'lives'),
#  ("'", 'lives', 'after'),
#  ('lives', 'after', 'the'),
#  ('after', 'the', 'clever'),
#  ('the', 'clever', 'credits'),
#  ('clever', 'credits', 'roll'),
#  ('credits', 'roll', 'you'),
#  ('roll', 'you', 'wondering'),
#  ('you', 'wondering', 'about'),
#  ('wondering', 'about', 'the'),
#  ('about', 'the', 'characters'),
#  ('the', 'characters', "'"),
#  ('characters', "'", 'lives'),
#  ("'", 'lives', 'after'),
#  ('lives', 'after', 'the'),
#  ('after', 'the', 'clever'),
#  ('the', 'clever', 'credits'),
#  ('clever', 'credits', 'roll'),
#  ('credits', 'roll', 'clever'),
#  ('roll', 'clever', 'This'),
#  ('clever', 'This', 'is'),
#  ('This', 'is', 'a'),
#  ('is', 'a', 'heartfelt'),
#  ('a', 'heartfelt', 'story'),
#  ('heartfelt', 'story', 'heartfelt'),
#  ('story', 'heartfelt', 'story'),
#  ('heartfelt', 'story', 'An'),
#  ('story', 'An', 'unsettling'),
#  ('An', 'unsettling', ','),
#  ('unsettling', ',', 'memorable'),
#  (',', 'memorable', 'cinematic'),
#  ('memorable', 'cinematic', 'experience'),
#  ('cinematic', 'experience', 'that'),
#  ('experience', 'that', 'does'),
#  ('that', 'does', 'its'),
#  ('does', 'its', 'predecessors'),
#  ('its', 'predecessors', 'proud'),
#  ('predecessors', 'proud', '.'),
#  ('proud', '.', 'An'),
#  ('.', 'An', 'unsettling'),
#  ('An', 'unsettling', ','),
#  ('unsettling', ',', 'memorable'),
#  (',', 'memorable', 'cinematic'),
#  ('memorable', 'cinematic', 'experience'),
#  ('cinematic', 'experience', 'that'),
#  ('experience', 'that', ','),
#  ('that', ',', 'memorable'),
#  (',', 'memorable', 'cinematic'),
#  ('memorable', 'cinematic', 'experience'),
#  ('cinematic', 'experience', 'does'),
#  ('experience', 'does', 'its'),
#  ('does', 'its', 'predecessors'),
#  ('its', 'predecessors', 'proud'),
#  ('predecessors', 'proud', 'proud'),
#  ('proud', 'proud', 'it'),
#  ('proud', 'it', "'s"),
#  ('it', "'s", 'a'),
#  ("'s", 'a', 'pretty'),
#  ('a', 'pretty', 'good'),
#  ('pretty', 'good', 'execution'),
#  ('good', 'execution', 'of'),
#  ('execution', 'of', 'a'),
#  ('of', 'a', 'story'),
#  ('a', 'story', 'that'),
#  ('story', 'that', "'s"),
#  ('that', "'s", 'a'),
#  ("'s", 'a', 'lot'),
#  ('a', 'lot', 'richer'),
#  ('lot', 'richer', 'than'),
#  ('richer', 'than', 'the'),
#  ('than', 'the', 'ones'),
#  ('the', 'ones', 'Hollywood'),
#  ('ones', 'Hollywood', 'action'),
#  ('Hollywood', 'action', 'screenwriters'),
#  ('action', 'screenwriters', 'usually'),
#  ('screenwriters', 'usually', 'come'),
#  ('usually', 'come', 'up'),
#  ('come', 'up', 'with'),
#  ('up', 'with', 'on'),
#  ('with', 'on', 'their'),
#  ('on', 'their', 'own'),
#  ('their', 'own', '.'),
#  ('own', '.', 'a'),
#  ('.', 'a', 'pretty'),
#  ('a', 'pretty', 'good'),
#  ('pretty', 'good', 'execution'),
#  ('good', 'execution', 'of'),
#  ('execution', 'of', 'a'),
#  ('of', 'a', 'story'),
#  ('a', 'story', 'that'),
#  ('story', 'that', "'s"),
#  ('that', "'s", 'a'),
#  ("'s", 'a', 'lot'),
#  ('a', 'lot', 'richer'),
#  ('lot', 'richer', 'than'),
#  ('richer', 'than', 'the'),
#  ('than', 'the', 'ones'),
#  ('the', 'ones', 'Hollywood'),
#  ('ones', 'Hollywood', 'action'),
#  ('Hollywood', 'action', 'screenwriters'),
#  ('action', 'screenwriters', 'usually'),
#  ('screenwriters', 'usually', 'come'),
#  ('usually', 'come', 'up'),
#  ('come', 'up', 'with'),
#  ('up', 'with', 'on'),
#  ('with', 'on', 'their'),
#  ('on', 'their', 'own'),
#  ('their', 'own', 'pretty'),
#  ('own', 'pretty', 'of'),
#  ('pretty', 'of', 'a'),
#  ('of', 'a', 'story'),
#  ('a', 'story', 'that'),
#  ('story', 'that', "'s"),
#  ('that', "'s", 'a'),
#  ("'s", 'a', 'lot'),
#  ('a', 'lot', 'richer'),
#  ('lot', 'richer', 'than'),
#  ('richer', 'than', 'the'),
#  ('than', 'the', 'ones'),
#  ('the', 'ones', 'Hollywood'),
#  ('ones', 'Hollywood', 'action'),
#  ('Hollywood', 'action', 'screenwriters'),
#  ('action', 'screenwriters', 'usually'),
#  ('screenwriters', 'usually', 'come'),
#  ('usually', 'come', 'up'),
#  ('come', 'up', 'with'),
#  ('up', 'with', 'on'),
#  ('with', 'on', 'their'),
#  ('on', 'their', 'own'),
#  ('their', 'own', 'a'),
#  ('own', 'a', 'story'),
#  ('a', 'story', 'that'),
#  ('story', 'that', "'s"),
#  ('that', "'s", 'a'),
#  ("'s", 'a', 'lot'),
#  ('a', 'lot', 'richer'),
#  ('lot', 'richer', 'than'),
#  ('richer', 'than', 'the'),
#  ('than', 'the', 'ones'),
#  ('the', 'ones', 'Hollywood'),
#  ('ones', 'Hollywood', 'action'),
#  ('Hollywood', 'action', 'screenwriters'),
#  ('action', 'screenwriters', 'usually'),
#  ('screenwriters', 'usually', 'come'),
#  ('usually', 'come', 'up'),
#  ('come', 'up', 'with'),
#  ('up', 'with', 'on'),
#  ('with', 'on', 'their'),
#  ('on', 'their', 'own'),
#  ('their', 'own', 'Inventive'),
#  ('own', 'Inventive', ','),
#  ('Inventive', ',', 'fun'),
#  (',', 'fun', 'sexy'),
#  ('fun', 'sexy', 'Tells'),
#  ('sexy', 'Tells', 'a'),
#  ('Tells', 'a', 'fascinating'),
#  ('a', 'fascinating', ','),
#  ('fascinating', ',', 'compelling'),
#  (',', 'compelling', 'story'),
#  ('compelling', 'story', '.'),
#  ('story', '.', 'a'),
#  ('.', 'a', 'fascinating'),
#  ('a', 'fascinating', ','),
#  ('fascinating', ',', 'compelling'),
#  (',', 'compelling', 'story'),
#  ('compelling', 'story', 'fascinating'),
#  ('story', 'fascinating', ','),
#  ('fascinating', ',', 'compelling'),
#  (',', 'compelling', 'story'),
#  ('compelling', 'story', 'Highly'),
#  ('story', 'Highly', 'recommended'),
#  ('Highly', 'recommended', 'viewing'),
#  ('recommended', 'viewing', 'for'),
#  ('viewing', 'for', 'its'),
#  ('for', 'its', 'courage'),
#  ('its', 'courage', ','),
#  ('courage', ',', 'ideas'),
#  (',', 'ideas', ','),
#  ('ideas', ',', 'technical'),
#  (',', 'technical', 'proficiency'),
#  ('technical', 'proficiency', 'and'),
#  ('proficiency', 'and', 'great'),
#  ('and', 'great', 'acting'),
#  ('great', 'acting', '.'),
#  ('acting', '.', 'recommended'),
#  ('.', 'recommended', 'viewing'),
#  ('recommended', 'viewing', 'for'),
#  ('viewing', 'for', 'its'),
#  ('for', 'its', 'courage'),
#  ('its', 'courage', ','),
#  ('courage', ',', 'ideas'),
#  (',', 'ideas', ','),
#  ('ideas', ',', 'technical'),
#  (',', 'technical', 'proficiency'),
#  ('technical', 'proficiency', 'and'),
#  ('proficiency', 'and', 'great'),
#  ('and', 'great', 'acting'),
#  ('great', 'acting', 'recommended'),
#  ('acting', 'recommended', 'for'),
#  ('recommended', 'for', 'its'),
#  ('for', 'its', 'courage'),
#  ('its', 'courage', ','),
#  ('courage', ',', 'ideas'),
#  (',', 'ideas', ','),
#  ('ideas', ',', 'technical'),
#  (',', 'technical', 'proficiency'),
#  ('technical', 'proficiency', 'and'),
#  ('proficiency', 'and', 'great'),
#  ('and', 'great', 'acting'),
#  ('great', 'acting', 'its'),
#  ('acting', 'its', 'courage'),
#  ('its', 'courage', ','),
#  ('courage', ',', 'ideas'),
#  (',', 'ideas', ','),
#  ('ideas', ',', 'technical'),
#  (',', 'technical', 'proficiency'),
#  ('technical', 'proficiency', 'and'),
#  ('proficiency', 'and', 'great'),
#  ('and', 'great', 'acting'),
#  ('great', 'acting', 'great'),
#  ('acting', 'great', 'acting'),
#  ('great', 'acting', 'great'),
#  ('acting', 'great', 'In'),
#  ('great', 'In', 'IMAX'),
#  ('In', 'IMAX', 'in'),
#  ('IMAX', 'in', 'short'),
#  ('in', 'short', ','),
#  ('short', ',', 'it'),
#  (',', 'it', "'s"),
#  ('it', "'s", 'just'),
#  ("'s", 'just', 'as'),
#  ('just', 'as', 'wonderful'),
#  ('as', 'wonderful', 'on'),
#  ('wonderful', 'on', 'the'),
#  ('on', 'the', 'big'),
#  ('the', 'big', 'screen'),
#  ('big', 'screen', '.'),
#  ('screen', '.', "'s"),
#  ('.', "'s", 'just'),
#  ("'s", 'just', 'as'),
#  ('just', 'as', 'wonderful'),
#  ('as', 'wonderful', 'on'),
#  ('wonderful', 'on', 'the'),
#  ('on', 'the', 'big'),
#  ('the', 'big', 'screen'),
#  ('big', 'screen', '.'),
#  ('screen', '.', 'as'),
#  ('.', 'as', 'wonderful'),
#  ('as', 'wonderful', 'on'),
#  ('wonderful', 'on', 'the'),
#  ('on', 'the', 'big'),
#  ('the', 'big', 'screen'),
#  ('big', 'screen', 'wonderful'),
#  ('screen', 'wonderful', 'on'),
#  ('wonderful', 'on', 'the'),
#  ...]

# %%
Counter(text_trigrams).most_common(30)
# Out:
# [(('one', 'of', 'the'), 1843),
#  (('of', 'the', 'year'), 935),
#  (('of', 'the', 'best'), 757),
#  (('of', 'the', 'most'), 682),
#  (('is', 'one', 'of'), 457),
#  (('One', 'of', 'the'), 413),
#  ((',', 'and', 'the'), 373),
#  (('the', 'year', "'s"), 364),
#  (('It', "'s", 'a'), 361),
#  (('.', 'is', 'a'), 351),
#  (('it', "'s", 'a'), 336),
#  (('the', 'edge', 'of'), 334),
#  (('a', 'movie', 'that'), 332),
#  (('of', 'your', 'seat'), 306),
#  (('the', 'kind', 'of'), 300),
#  (('the', 'film', 'is'), 298),
#  (('the', 'film', "'s"), 295),
#  (('as', 'one', 'of'), 284),
#  ((',', 'the', 'film'), 283),
#  (('edge', 'of', 'your'), 278),
#  ((',', 'this', 'is'), 267),
#  (('as', 'well', 'as'), 258),
#  ((',', 'it', "'s"), 253),
#  (('film', 'that', 'is'), 253),
#  (('a', 'film', 'that'), 238),
#  (('.', 'It', "'s"), 234),
#  ((',', 'funny', ','), 233),
#  (('some', 'of', 'the'), 229),
#  (('year', "'s", 'best'), 209),
#  (('a', 'solid', 'cast'), 198)]

# %%
tokenizer = TweetTokenizer()
tokenizer.tokenize
# Out:
# <bound method TweetTokenizer.tokenize of <nltk.tokenize.casual.TweetTokenizer object at 0x000002230596EE08>>

# %%
vectorizer = TfidfVectorizer(ngram_range = (1,2), tokenizer = tokenizer.tokenize)
full_text = list(data_resampled['Revised_Phrase'].values)
vectorizer.fit(full_text)
data_resampled_vectorized = vectorizer.transform(data_resampled['Revised_Phrase'])

y = data_resampled['Sentiment']
data_resampled_vectorized
# Out:
# <531060x90751 sparse matrix of type '<class 'numpy.float64'>'
# 	with 7836632 stored elements in Compressed Sparse Row format>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.model_selection import train_test_split, cross_val_score

# %%
LogisReg = LogisticRegression()
ovr = OneVsRestClassifier(LogisReg)

# %%
# %%time
ovr.fit(data_resampled_vectorized, y)
# Out:
# C:\Users\Sambudh\Anaconda3\envs\tf-gpu\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Wall time: 44.8 s
# OneVsRestClassifier(estimator=LogisticRegression(C=1.0, class_weight=None,
#                                                  dual=False, fit_intercept=True,
#                                                  intercept_scaling=1,
#                                                  l1_ratio=None, max_iter=100,
#                                                  multi_class='warn',
#                                                  n_jobs=None, penalty='l2',
#                                                  random_state=None,
#                                                  solver='warn', tol=0.0001,
#                                                  verbose=0, warm_start=False),
#                     n_jobs=None)

# %%
scores = cross_val_score(ovr, data_resampled_vectorized, y, scoring = 'accuracy',n_jobs = -1, cv = 3)
print('Cross-validation mean accuracy {0:.2f}%, std {1: .2f}.'.format(np.mean(scores) * 100, np.std(scores) * 100))
# Out:
# Cross-validation mean accuracy 76.15%, std  0.78.

# %%
from tensorflow.keras.utils import to_categorical
X = data_resampled['Revised_Phrase'].values
Y = to_categorical(data_resampled['Sentiment'].values)
X
# Out:
# array(['a series of escapade demonstrating the adage that what is good for the goose is also good for the gander some of which occasionally amuses but none of which amount to much of a story',
#        'the gander some of which occasionally amuses but none of which amount to much of a story',
#        'but none of which amount to much of a story', ...,
#        'waste viewer time',
#        'much about the film including some of it casting is frustratingly unconvincing',
#        'it s uninteresting'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, Y_train, Y_val = train_test_split(X, Y, test_size=0.25, random_state=123)
X_train
# Out:
# array(['barney s idea about creation and identity do n t really seem all that profound at least by way of what can be gleaned from this three hour endurance test built around an hour s worth of actual material',
#        'is more interesting lrb and funnier rrb', 'greatest mistake', ...,
#        'to mention dragged down by a leaden closing act',
#        'about otherwise dull subject',
#        'may lack the pungent bite of it title but it s an enjoyable trifle nonetheless'],
#       dtype=object)

# %%
print(X_train.shape,Y_train.shape)
print(X_val.shape,Y_val.shape)
# Out:
# (398295, 48) (398295, 5)
# (132765, 48) (132765, 5)

# %%
from nltk import FreqDist

# %%
all_words=' '.join(X_train)
all_words=word_tokenize(all_words)
#print(all_words)
dist=FreqDist(all_words)

num_unique_word=len(dist)
num_unique_word
#X_train.head()
# Out:
# 13744

# %%
r_len=[]
for text in X_train:
    word=word_tokenize(text)
    l=len(word)
    r_len.append(l)
    
MAX_REVIEW_LEN=np.max(r_len)
MAX_REVIEW_LEN
# Out:
# 48

# %%
max_features = num_unique_word
max_words = MAX_REVIEW_LEN
batch_size = 128
epochs = 3
num_classes=5

# %%
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_val = tokenizer.texts_to_sequences(X_val)

# %%
from tensorflow.keras.preprocessing import sequence,text
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.sequence import pad_sequences
X_train = sequence.pad_sequences(X_train, maxlen=max_words)
X_val = sequence.pad_sequences(X_val, maxlen=max_words)
#print(X_train.shape,X_val.shape)
X_train
# Out:
# array([[   0,    0,    0, ...,    4, 2260,  224],
#        [   0,    0,    0, ...,    3,  979,   52],
#        [   0,    0,    0, ...,    0,  824, 1697],
#        ...,
#        [   0,    0,    0, ..., 1501, 2401,  377],
#        [   0,    0,    0, ...,  559,  202,  213],
#        [   0,    0,    0, ...,  293, 2427, 5597]])

# %%
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.optimizers import Adam

# %%
model1=Sequential()
model1.add(Embedding(max_features,100,mask_zero=True))

model1.add(LSTM(64,dropout=0.4, recurrent_dropout=0.4,return_sequences=True))
model1.add(LSTM(32,dropout=0.5, recurrent_dropout=0.5,return_sequences=False))
model1.add(Dense(num_classes,activation='softmax'))


model1.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.001),metrics=['accuracy'])
model1.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, None, 100)         1374400
# _________________________________________________________________
# lstm_4 (LSTM)                (None, None, 64)          42240
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 165
# =================================================================
# Total params: 1,429,221
# Trainable params: 1,429,221
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.fit(X_train, Y_train, validation_data=(X_val, Y_val),epochs=epochs, batch_size=batch_size, verbose=1)
# Out:
# Train on 398295 samples, validate on 132765 samples
# Epoch 1/3
# 398295/398295 [==============================] - 650s 2ms/sample - loss: 0.9548 - accuracy: 0.6024 - val_loss: 0.7849 - val_accuracy: 0.6777
# Epoch 2/3
# 398295/398295 [==============================] - 687s 2ms/sample - loss: 0.7692 - accuracy: 0.6839 - val_loss: 0.7121 - val_accuracy: 0.7081
# Epoch 3/3
# 398295/398295 [==============================] - 836s 2ms/sample - loss: 0.7063 - accuracy: 0.7103 - val_loss: 0.6672 - val_accuracy: 0.7259

# %%
text1 = "This movie is fantastic! I really like it because it is so good!"
text2 = "Good movie!"
text3 = "Maybe I like this movie."
text4 = "Meh ..."
text5 = "If I were a drunk teenager then this movie might be good."
text6 = "Bad movie!"
text7 = "Not a good movie!"
text8 = "This movie really sucks! Can I get my money back please?"
texts = [text1, text2, text3, text4, text5, text6, text7, text8]

# %%
tokens = tokenizer.texts_to_sequences(texts)
tokens
# Out:
# [[16, 12, 8, 1090, 49, 118, 35, 6, 165, 6, 8, 33, 45],
#  [45, 12],
#  [1020, 49, 35, 16, 12],
#  [],
#  [60, 49, 197, 2, 3936, 1576, 316, 16, 12, 187, 18, 45],
#  [53, 12],
#  [27, 2, 45, 12],
#  [16, 12, 118, 66, 49, 94, 193, 615, 205, 1508]]

# %%
tokens_pad = pad_sequences(tokens, maxlen=MAX_REVIEW_LEN)
tokens_pad.shape
# Out:
# (8, 48)

# %%
prediction=model1.predict_classes(tokens_pad,verbose=1)
# Out:
# 8/1 [================================================================================================================================================================================================================================================] - 0s 4ms/sample

# %%
print(prediction)
# Out:
# [4 4 2 2 1 0 1 0]

# %%
test = pd.read_csv('test.tsv', sep="\t")
test.head()
# Out:
#    PhraseId  SentenceId                                             Phrase
# 0    156061        8545  An intermittently pleasing but mostly routine ...
# 1    156062        8545  An intermittently pleasing but mostly routine ...
# 2    156063        8545                                                 An
# 3    156064        8545  intermittently pleasing but mostly routine effort
# 4    156065        8545         intermittently pleasing but mostly routine

# %%
test['clean_review']=clean_data(test.Phrase.values)
test.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0    156061        8545  An intermittently pleasing but mostly routine ...
# 1    156062        8545  An intermittently pleasing but mostly routine ...
# 2    156063        8545                                                 An
# 3    156064        8545  intermittently pleasing but mostly routine effort
# 4    156065        8545         intermittently pleasing but mostly routine
#
#                                         clean_review
# 0  an intermittently pleasing but mostly routine ...
# 1  an intermittently pleasing but mostly routine ...
# 2                                                 an
# 3  intermittently pleasing but mostly routine effort
# 4         intermittently pleasing but mostly routine

# %%
test_vectorized = vectorizer.transform(test['clean_review'])
test1 = test['clean_review'].values

# %%
X_test = tokenizer.texts_to_sequences(test1)
X_test
# Out:
# [[15, 3330, 1560, 20, 719, 789, 347],
#  [15, 3330, 1560, 20, 719, 789, 347],
#  [15],
#  [3330, 1560, 20, 719, 789, 347],
#  [3330, 1560, 20, 719, 789],
#  [3330, 1560, 20],
#  [3330, 1560],
#  [3330],
#  [1560],
#  [20],
#  [719, 789],
#  [719],
#  [789],
#  [347],
#  [],
#  [2882,
#   8,
#   118,
#   1,
#   82,
#   101,
#   10,
#   7,
#   226,
#   218,
#   9,
#   3122,
#   328,
#   2,
#   11,
#   24,
#   1,
#   1411,
#   10543,
#   9782,
#   9783,
#   55,
#   6385,
#   52,
#   10,
#   2144,
#   2,
#   245,
#   154,
#   1611,
#   4,
#   1,
#   524,
#   13022,
#   4,
#   911,
#   48,
#   9,
#   1,
#   1266,
#   211,
#   1525,
#   141],
#  [2882],
#  [8,
#   118,
#   1,
#   82,
#   101,
#   10,
#   7,
#   226,
#   218,
#   9,
#   3122,
#   328,
#   2,
#   11,
#   24,
#   1,
#   1411,
#   10543,
#   9782,
#   9783,
#   55,
#   6385,
#   52,
#   10,
#   2144,
#   2,
#   245,
#   154,
#   1611,
#   4,
#   1,
#   524,
#   13022,
#   4,
#   911,
#   48,
#   9,
#   1,
#   1266,
#   211,
#   1525,
#   141],
#  [8,
#   118,
#   1,
#   82,
#   101,
#   10,
#   7,
#   226,
#   218,
#   9,
#   3122,
#   328,
#   2,
#   11,
#   24,
#   1,
#   1411,
#   10543,
#   9782,
#   9783,
#   55,
#   6385,
#   52,
#   10,
#   2144,
#   2,
#   245,
#   154,
#   1611,
#   4,
#   1,
#   524,
#   13022,
#   4,
#   911,
#   48,
#   9,
#   1,
#   1266,
#   211,
#   1525,
#   141],
#  [8, 118],
#  [8],
#  [118],
#  [1,
#   82,
#   101,
#   10,
#   7,
#   226,
#   218,
#   9,
#   3122,
#   328,
#   2,
#   11,
#   24,
#   1,
#   1411,
#   10543,
#   9782,
#   9783,
#   55,
#   6385,
#   52,
#   10,
#   2144,
#   2,
#   245,
#   154,
#   1611,
#   4,
#   1,
#   524,
#   13022,
#   4,
#   911,
#   48,
#   9,
#   1,
#   1266,
#   211,
#   1525,
#   141],
#  [1, 82, 101],
#  [1],
#  [82, 101],
#  [82],
#  [101],
#  [10,
#   7,
#   226,
#   218,
#   9,
#   3122,
#   328,
#   2,
#   11,
#   24,
#   1,
#   1411,
#   10543,
#   9782,
#   9783,
#   55,
#   6385,
#   52,
#   10,
#   2144,
#   2,
#   245,
#   154,
#   1611,
#   4,
#   1,
#   524,
#   13022,
#   4,
#   911,
#   48,
#   9,
#   1,
#   1266,
#   211,
#   1525,
#   141],
#  [10],
#  [7,
#   226,
#   218,
#   9,
#   3122,
#   328,
#   2,
#   11,
#   24,
#   1,
#   1411,
#   10543,
#   9782,
#   9783,
#   55,
#   6385,
#   52,
#   10,
#   2144,
#   2,
#   245,
#   154,
#   1611,
#   4,
#   1,
#   524,
#   13022,
#   4,
#   911,
#   48,
#   9,
#   1,
#   1266,
#   211,
#   1525,
#   141],
#  [7,
#   226,
#   218,
#   9,
#   3122,
#   328,
#   2,
#   11,
#   24,
#   1,
#   1411,
#   10543,
#   9782,
#   9783,
#   55,
#   6385,
#   52,
#   10,
#   2144,
#   2,
#   245,
#   154,
#   1611,
#   4,
#   1,
#   524,
#   13022,
#   4,
#   911,
#   48],
#  [7,
#   226,
#   218,
#   9,
#   3122,
#   328,
#   2,
#   11,
#   24,
#   1,
#   1411,
#   10543,
#   9782,
#   9783,
#   55,
#   6385,
#   52,
#   10,
#   2144],
#  [7, 226],
#  [7],
#  [226],
#  [218,
#   9,
#   3122,
#   328,
#   2,
#   11,
#   24,
#   1,
#   1411,
#   10543,
#   9782,
#   9783,
#   55,
#   6385,
#   52,
#   10,
#   2144],
#  [218, 9, 3122, 328, 2, 11],
#  [218],
#  [9, 3122, 328, 2, 11],
#  [9],
#  [3122, 328, 2, 11],
#  [3122, 328],
#  [3122, 328],
#  [3122],
#  [328],
#  [],
#  [2, 11],
#  [2],
#  [11],
#  [24, 1, 1411, 10543, 9782, 9783, 55, 6385, 52, 10, 2144],
#  [24],
#  [1, 1411, 10543, 9782, 9783, 55, 6385, 52, 10, 2144],
#  [1, 1411, 10543, 9782, 9783, 55, 6385, 52],
#  [1, 1411, 10543, 9782, 9783],
#  [1411, 10543, 9782, 9783],
#  [1411, 10543],
#  [9782, 9783],
#  [9782],
#  [9783],
#  [55, 6385, 52],
#  [55],
#  [6385, 52],
#  [6385],
#  [52],
#  [10, 2144],
#  [2144],
#  [2, 245, 154, 1611, 4, 1, 524, 13022, 4, 911, 48],
#  [2],
#  [245, 154, 1611, 4, 1, 524, 13022, 4, 911, 48],
#  [245],
#  [154, 1611, 4, 1, 524, 13022, 4, 911, 48],
#  [154, 1611],
#  [154],
#  [1611],
#  [4, 1, 524, 13022, 4, 911, 48],
#  [4],
#  [1, 524, 13022, 4, 911, 48],
#  [1, 524, 13022],
#  [524, 13022],
#  [524],
#  [13022],
#  [4, 911, 48],
#  [911, 48],
#  [911],
#  [48],
#  [9, 1, 1266, 211, 1525, 141],
#  [1, 1266, 211, 1525, 141],
#  [1266, 211, 1525, 141],
#  [1266, 211],
#  [1525, 141],
#  [1525],
#  [141],
#  [332, 17, 94, 51, 6, 793, 1, 12, 390, 2, 3026, 216],
#  [332, 17, 94, 51, 6, 793],
#  [332],
#  [17, 94, 51, 6, 793],
#  [17],
#  [94, 51, 6, 793],
#  [94],
#  [51, 6, 793],
#  [51],
#  [6, 793],
#  [6],
#  [793],
#  [1, 12, 390, 2, 3026, 216],
#  [],
#  [1, 12, 390, 2, 3026, 216],
#  [1, 12],
#  [12],
#  [390, 2, 3026, 216],
#  [390, 2, 3026, 216],
#  [390],
#  [2, 3026, 216],
#  [3026, 216],
#  [3026],
#  [216],
#  [49,
#   6289,
#   3693,
#   49,
#   92,
#   218,
#   2,
#   185,
#   30,
#   1,
#   6402,
#   3,
#   65,
#   98,
#   1509,
#   443,
#   4,
#   32,
#   16,
#   163,
#   36],
#  [49],
#  [6289,
#   3693,
#   49,
#   92,
#   218,
#   2,
#   185,
#   30,
#   1,
#   6402,
#   3,
#   65,
#   98,
#   1509,
#   443,
#   4,
#   32,
#   16,
#   163,
#   36],
#  [6289,
#   3693,
#   49,
#   92,
#   218,
#   2,
#   185,
#   30,
#   1,
#   6402,
#   3,
#   65,
#   98,
#   1509,
#   443,
#   4,
#   32,
#   16,
#   163,
#   36],
#  [6289],
#  [3693,
#   49,
#   92,
#   218,
#   2,
#   185,
#   30,
#   1,
#   6402,
#   3,
#   65,
#   98,
#   1509,
#   443,
#   4,
#   32,
#   16,
#   163,
#   36],
#  [3693],
#  [49, 92, 218, 2, 185, 30, 1, 6402, 3, 65, 98, 1509, 443, 4, 32, 16, 163, 36],
#  [49, 92, 218, 2, 185, 30, 1, 6402, 3],
#  [49, 92, 218, 2, 185, 30, 1, 6402],
#  [92, 218, 2, 185, 30, 1, 6402],
#  [92],
#  [218, 2, 185, 30, 1, 6402],
#  [2, 185, 30, 1, 6402],
#  [2, 185],
#  [185],
#  [30, 1, 6402],
#  [30],
#  [1, 6402],
#  [6402],
#  [6402],
#  [],
#  [3],
#  [65, 98, 1509, 443, 4, 32, 16, 163, 36],
#  [65],
#  [98, 1509, 443, 4, 32, 16, 163, 36],
#  [98],
#  [1509, 443, 4, 32, 16, 163, 36],
#  [1509],
#  [443, 4, 32, 16, 163, 36],
#  [443],
#  [4, 32, 16, 163, 36],
#  [32, 16, 163, 36],
#  [32, 16],
#  [32],
#  [16],
#  [16],
#  [],
#  [163, 36],
#  [163],
#  [36],
#  [8353,
#   72,
#   23,
#   22,
#   1869,
#   14,
#   219,
#   1609,
#   20,
#   191,
#   815,
#   2,
#   58,
#   4,
#   1255,
#   660,
#   3,
#   673],
#  [8353],
#  [72, 23, 22, 1869, 14, 219, 1609, 20, 191, 815, 2, 58, 4, 1255, 660, 3, 673],
#  [72, 23, 22, 1869, 14, 219, 1609, 20, 191, 815, 2, 58, 4, 1255, 660, 3, 673],
#  [72, 23, 22, 1869, 14, 219, 1609, 20],
#  [72, 23, 22, 1869, 14, 219, 1609],
#  [72, 23, 22, 1869, 14, 219, 1609],
#  [72, 23, 22],
#  [72],
#  [23, 22],
#  [1869, 14, 219, 1609],
#  [1869],
#  [14, 219, 1609],
#  [14],
#  [219, 1609],
#  [219],
#  [1609],
#  [191, 815, 2, 58, 4, 1255, 660, 3, 673],
#  [191],
#  [815, 2, 58, 4, 1255, 660, 3, 673],
#  [815],
#  [2, 58, 4, 1255, 660, 3, 673],
#  [2, 58],
#  [58],
#  [4, 1255, 660, 3, 673],
#  [1255, 660, 3, 673],
#  [1255],
#  [660, 3, 673],
#  [660, 3],
#  [660],
#  [673],
#  [32, 145, 67, 499, 4, 20, 1, 271, 162, 100, 12110],
#  [32, 145, 67, 499, 4, 20, 1, 271, 162, 100, 12110],
#  [32, 145, 67, 499, 4, 20],
#  [32, 145, 67, 499, 4],
#  [32, 145, 67, 499, 4],
#  [145, 67, 499, 4],
#  [145, 67],
#  [145, 67],
#  [145],
#  [67],
#  [499, 4],
#  [499],
#  [1, 271, 162, 100, 12110],
#  [1, 271, 162],
#  [271, 162],
#  [],
#  [271, 162],
#  [271],
#  [162],
#  [100, 12110],
#  [100],
#  [12110],
#  [6,
#   7,
#   2,
#   3177,
#   3,
#   2,
#   222,
#   3,
#   2,
#   112,
#   64,
#   14,
#   1,
#   186,
#   123,
#   5,
#   106,
#   65,
#   2,
#   9484,
#   8,
#   35,
#   116,
#   86,
#   7,
#   27,
#   1366,
#   1,
#   259],
#  [6],
#  [7,
#   2,
#   3177,
#   3,
#   2,
#   222,
#   3,
#   2,
#   112,
#   64,
#   14,
#   1,
#   186,
#   123,
#   5,
#   106,
#   65,
#   2,
#   9484,
#   8,
#   35,
#   116,
#   86,
#   7,
#   27,
#   1366,
#   1,
#   259],
#  [7,
#   2,
#   3177,
#   3,
#   2,
#   222,
#   3,
#   2,
#   112,
#   64,
#   14,
#   1,
#   186,
#   123,
#   5,
#   106,
#   65,
#   2,
#   9484,
#   8,
#   35,
#   116,
#   86,
#   7,
#   27,
#   1366,
#   1,
#   259],
#  [7, 2, 3177, 3, 2, 222, 3, 2, 112, 64, 14, 1, 186, 123],
#  [2, 3177, 3, 2, 222, 3, 2, 112, 64, 14, 1, 186, 123],
#  [2, 3177, 3, 2, 222, 3],
#  [2, 3177, 3, 2, 222],
#  [2, 3177, 3, 2, 222],
#  [2, 3177, 3],
#  [2, 3177],
#  [3177],
#  [2, 222],
#  [222],
#  [2, 112, 64, 14, 1, 186, 123],
#  [2, 112, 64],
#  [112, 64],
#  [112],
#  [64],
#  [14, 1, 186, 123],
#  [1, 186, 123],
#  [186, 123],
#  [186],
#  [123],
#  [5, 106, 65, 2, 9484, 8, 35, 116, 86, 7, 27, 1366, 1, 259],
#  [5],
#  [106, 65, 2, 9484, 8, 35, 116, 86, 7, 27, 1366, 1, 259],
#  [106],
#  [65, 2, 9484, 8, 35, 116, 86, 7, 27, 1366, 1, 259],
#  [2, 9484, 8, 35, 116, 86, 7, 27, 1366, 1, 259],
#  [2, 9484],
#  [9484],
#  [8, 35, 116, 86, 7, 27, 1366, 1, 259],
#  [35, 116, 86, 7, 27, 1366, 1, 259],
#  [35],
#  [116, 86, 7, 27, 1366, 1, 259],
#  [116],
#  [86, 7, 27, 1366, 1, 259],
#  [86],
#  [7, 27, 1366, 1, 259],
#  [7, 27],
#  [27],
#  [1366, 1, 259],
#  [1366],
#  [1, 259],
#  [259],
#  [259],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [1,
#   1796,
#   4,
#   1,
#   190,
#   1,
#   10121,
#   4,
#   1,
#   1830,
#   494,
#   3,
#   1,
#   6396,
#   11517,
#   9,
#   1,
#   3370,
#   1834,
#   1490,
#   3142,
#   97],
#  [1,
#   1796,
#   4,
#   1,
#   190,
#   1,
#   10121,
#   4,
#   1,
#   1830,
#   494,
#   3,
#   1,
#   6396,
#   11517,
#   9,
#   1,
#   3370,
#   1834],
#  [1, 1796],
#  [1796],
#  [4, 1, 190, 1, 10121, 4, 1, 1830, 494, 3, 1, 6396, 11517, 9, 1, 3370, 1834],
#  [1, 190, 1, 10121, 4, 1, 1830, 494, 3, 1, 6396, 11517, 9, 1, 3370, 1834],
#  [1, 190],
#  [1, 190],
#  [190],
#  [1, 10121, 4, 1, 1830, 494, 3, 1, 6396, 11517, 9, 1, 3370, 1834],
#  [1, 10121, 4, 1, 1830, 494, 3],
#  [1, 10121, 4, 1, 1830, 494],
#  [1, 10121, 4, 1, 1830, 494],
#  [1, 10121],
#  [10121],
#  [10121],
#  [],
#  [4, 1, 1830, 494],
#  [1, 1830, 494],
#  [1830, 494],
#  [1830],
#  [494],
#  [1, 6396, 11517, 9, 1, 3370, 1834],
#  [1, 6396],
#  [6396],
#  [11517, 9, 1, 3370, 1834],
#  [11517],
#  [9, 1, 3370, 1834],
#  [1, 3370, 1834],
#  [3370, 1834],
#  [3370],
#  [1834],
#  [1490, 3142, 97],
#  [1490, 3142, 97],
#  [1490, 3142],
#  [1490],
#  [3142],
#  [97],
#  [1,
#   11,
#   3976,
#   54,
#   45,
#   322,
#   54,
#   45,
#   164,
#   544,
#   2,
#   162,
#   116,
#   2511,
#   7,
#   1788,
#   679,
#   503,
#   1307,
#   512,
#   1,
#   336,
#   4,
#   1624],
#  [1, 11],
#  [3976,
#   54,
#   45,
#   322,
#   54,
#   45,
#   164,
#   544,
#   2,
#   162,
#   116,
#   2511,
#   7,
#   1788,
#   679,
#   503,
#   1307,
#   512,
#   1,
#   336,
#   4,
#   1624],
#  [3976,
#   54,
#   45,
#   322,
#   54,
#   45,
#   164,
#   544,
#   2,
#   162,
#   116,
#   2511,
#   7,
#   1788,
#   679,
#   503,
#   1307,
#   512,
#   1,
#   336,
#   4,
#   1624],
#  [3976],
#  [54,
#   45,
#   322,
#   54,
#   45,
#   164,
#   544,
#   2,
#   162,
#   116,
#   2511,
#   7,
#   1788,
#   679,
#   503,
#   1307,
#   512,
#   1,
#   336,
#   4,
#   1624],
#  [54, 45, 322, 54, 45, 164, 544, 2, 162],
#  [54, 45, 322, 54, 45, 164],
#  [54, 45, 322, 54, 45, 164],
#  [54, 45, 322],
#  [54, 45, 322],
#  [54],
#  [45, 322],
#  [45],
#  [322],
#  [54, 45, 164],
#  [45, 164],
#  [164],
#  [544, 2, 162],
#  [544],
#  [2, 162],
#  [162],
#  [116, 2511, 7, 1788, 679, 503, 1307, 512, 1, 336, 4, 1624],
#  [2511, 7, 1788, 679, 503, 1307, 512, 1, 336, 4, 1624],
#  [2511, 7, 1788, 679, 503],
#  [2511, 7],
#  [2511],
#  [1788, 679, 503],
#  [1788],
#  [679, 503],
#  [679],
#  [503],
#  [503],
#  [],
#  [1307, 512, 1, 336, 4, 1624],
#  [1307],
#  [512, 1, 336, 4, 1624],
#  [512],
#  [1, 336, 4, 1624],
#  [1, 336],
#  [336],
#  [4, 1624],
#  [1624],
#  [15, 1602, 317, 714, 3, 367, 747, 742, 11, 30, 1, 320, 943, 4, 1, 1135],
#  [15, 1602, 317, 714, 3, 367, 747, 742, 11, 30, 1, 320, 943, 4, 1, 1135],
#  [15, 1602, 317, 714, 3, 367, 747, 742, 11],
#  [1602, 317, 714, 3, 367, 747, 742, 11],
#  [1602],
#  [317, 714, 3, 367, 747, 742, 11],
#  [317, 714, 3, 367, 747, 742, 11],
#  [317, 714, 3, 367, 747],
#  [317, 714, 3],
#  [317, 714],
#  [317],
#  [714],
#  [367, 747],
#  [367],
#  [747],
#  [742, 11],
#  [742],
#  [30, 1, 320, 943, 4, 1, 1135],
#  [1, 320, 943, 4, 1, 1135],
#  [1, 320, 943],
#  [320, 943],
#  [320],
#  [943],
#  [4, 1, 1135],
#  [1, 1135],
#  [1135],
#  [6,
#   2771,
#   1,
#   1356,
#   283,
#   4,
#   1535,
#   4202,
#   29,
#   1,
#   161,
#   4,
#   8235,
#   10,
#   8,
#   314,
#   24,
#   1,
#   7718,
#   4083,
#   1535,
#   5,
#   1,
#   957,
#   3,
#   252,
#   907,
#   4418,
#   4,
#   3038,
#   35,
#   12687,
#   3,
#   12688],
#  [2771,
#   1,
#   1356,
#   283,
#   4,
#   1535,
#   4202,
#   29,
#   1,
#   161,
#   4,
#   8235,
#   10,
#   8,
#   314,
#   24,
#   1,
#   7718,
#   4083,
#   1535,
#   5,
#   1,
#   957,
#   3,
#   252,
#   907,
#   4418,
#   4,
#   3038,
#   35,
#   12687,
#   3,
#   12688],
#  [2771,
#   1,
#   1356,
#   283,
#   4,
#   1535,
#   4202,
#   29,
#   1,
#   161,
#   4,
#   8235,
#   10,
#   8,
#   314,
#   24,
#   1,
#   7718,
#   4083,
#   1535,
#   5,
#   1,
#   957,
#   3,
#   252,
#   907,
#   4418,
#   4,
#   3038,
#   35,
#   12687,
#   3,
#   12688],
#  [2771, 1, 1356, 283, 4, 1535, 4202],
#  [2771, 1, 1356, 283, 4, 1535, 4202],
#  [2771],
#  [1, 1356, 283, 4, 1535, 4202],
#  [1, 1356, 283],
#  [1356, 283],
#  [1356],
#  [283],
#  [4, 1535, 4202],
#  [1535, 4202],
#  [1535],
#  [4202],
#  [29,
#   1,
#   161,
#   4,
#   8235,
#   10,
#   8,
#   314,
#   24,
#   1,
#   7718,
#   4083,
#   1535,
#   5,
#   1,
#   957,
#   3,
#   252,
#   907,
#   4418,
#   4,
#   3038,
#   35,
#   12687,
#   3,
#   12688],
#  [29],
#  [1,
#   161,
#   4,
#   8235,
#   10,
#   8,
#   314,
#   24,
#   1,
#   7718,
#   4083,
#   1535,
#   5,
#   1,
#   957,
#   3,
#   252,
#   907,
#   4418,
#   4,
#   3038,
#   35,
#   12687,
#   3,
#   12688],
#  [1, 161],
#  [161],
#  [4,
#   8235,
#   10,
#   8,
#   314,
#   24,
#   1,
#   7718,
#   4083,
#   1535,
#   5,
#   1,
#   957,
#   3,
#   252,
#   907,
#   4418,
#   4,
#   3038,
#   35,
#   12687,
#   3,
#   12688],
#  [8235,
#   10,
#   8,
#   314,
#   24,
#   1,
#   7718,
#   4083,
#   1535,
#   5,
#   1,
#   957,
#   3,
#   252,
#   907,
#   4418,
#   4,
#   3038,
#   35,
#   12687,
#   3,
#   12688],
#  [8235],
#  [10,
#   8,
#   314,
#   24,
#   1,
#   7718,
#   4083,
#   1535,
#   5,
#   1,
#   957,
#   3,
#   252,
#   907,
#   4418,
#   4,
#   3038,
#   35,
#   12687,
#   3,
#   12688],
#  [8,
#   314,
#   24,
#   1,
#   7718,
#   4083,
#   1535,
#   5,
#   1,
#   957,
#   3,
#   252,
#   907,
#   4418,
#   4,
#   3038,
#   35,
#   12687,
#   3,
#   12688],
#  [314,
#   24,
#   1,
#   7718,
#   4083,
#   1535,
#   5,
#   1,
#   957,
#   3,
#   252,
#   907,
#   4418,
#   4,
#   3038,
#   35,
#   12687,
#   3,
#   12688],
#  [314, 24, 1, 7718, 4083, 1535],
#  [314, 24, 1, 7718, 4083, 1535],
#  [314],
#  [24, 1, 7718, 4083, 1535],
#  [1, 7718, 4083, 1535],
#  [7718, 4083, 1535],
#  [7718, 4083],
#  [7718],
#  [4083],
#  [5, 1, 957, 3, 252, 907, 4418, 4, 3038, 35, 12687, 3, 12688],
#  [1, 957, 3, 252, 907, 4418, 4, 3038, 35, 12687, 3, 12688],
#  [1, 957, 3, 252, 907, 4418],
#  [957, 3, 252, 907, 4418],
#  [957, 3, 252, 907],
#  [957, 3],
#  [957],
#  [252, 907],
#  [252],
#  [907],
#  [4418],
#  [4, 3038, 35, 12687, 3, 12688],
#  [3038, 35, 12687, 3, 12688],
#  [3038],
#  [],
#  [3038],
#  [35, 12687, 3, 12688],
#  [12687, 3, 12688],
#  [12687, 3],
#  [12687],
#  [12688],
#  [2,
#   2052,
#   30,
#   31,
#   3,
#   31,
#   2707,
#   17,
#   14,
#   2,
#   175,
#   371,
#   262,
#   34,
#   9571,
#   19,
#   1,
#   9201,
#   5,
#   11967,
#   101,
#   47],
#  [2, 2052, 30, 31, 3, 31, 2707],
#  [2052, 30, 31, 3, 31, 2707],
#  [],
#  [2052, 30, 31, 3, 31, 2707],
#  [2052],
#  [30, 31, 3, 31, 2707],
#  [31, 3, 31, 2707],
#  [31, 3],
#  [31],
#  [],
#  [31],
#  [31],
#  [],
#  [31, 2707],
#  [],
#  [31, 2707],
#  [2707],
#  [17, 14, 2, 175, 371, 262, 34, 9571, 19, 1, 9201, 5, 11967, 101, 47],
#  [17, 14, 2, 175, 371, 262, 34, 9571, 19, 1, 9201, 5, 11967, 101, 47],
#  [14, 2, 175, 371, 262, 34, 9571, 19, 1, 9201, 5, 11967, 101, 47],
#  [14, 2, 175, 371, 262, 34, 9571, 19, 1, 9201, 5, 11967, 101, 47],
#  [],
#  [14, 2, 175, 371, 262, 34, 9571, 19, 1, 9201, 5, 11967, 101, 47],
#  [2, 175, 371, 262, 34, 9571, 19, 1, 9201, 5, 11967, 101, 47],
#  [2, 175, 371, 262, 34],
#  [2, 175, 371, 262],
#  [175, 371, 262],
#  [175],
#  [371, 262],
#  [],
#  [371, 262],
#  [371],
#  [262],
#  [34],
#  [9571, 19, 1, 9201, 5, 11967, 101, 47],
#  [9571],
#  [],
#  [9571],
#  [19, 1, 9201, 5, 11967, 101, 47],
#  [19],
#  [1, 9201, 5, 11967, 101, 47],
#  [9201, 5, 11967, 101, 47],
#  [9201],
#  [5, 11967, 101, 47],
#  [11967, 101, 47],
#  [11967, 101],
#  [11967],
#  [101],
#  [47],
#  [14, 32, 6, 3442, 2099, 2656, 1165, 4, 1, 1223, 1223, 3798, 8, 9, 2, 64],
#  [14, 32, 6, 3442, 2099],
#  [32, 6, 3442, 2099],
#  [6, 3442, 2099],
#  [3442, 2099],
#  [3442],
#  [2099],
#  [2656, 1165, 4, 1, 1223, 1223, 3798, 8, 9, 2, 64],
#  [2656, 1165, 4, 1, 1223, 1223, 3798, 8, 9, 2, 64],
#  [2656, 1165, 4, 1, 1223, 1223, 3798],
#  [2656, 1165],
#  [2656],
#  [1165],
#  [4, 1, 1223, 1223, 3798],
#  [1, 1223, 1223, 3798],
#  [1223, 1223, 3798],
#  [1223, 1223],
#  [3798],
#  [8, 9, 2, 64],
#  [8, 9, 2, 64],
#  [8],
#  [8],
#  [],
#  [9, 2, 64],
#  [2, 64],
#  [2],
#  [2],
#  [],
#  [64],
#  [],
#  [6,
#   93,
#   18,
#   157,
#   5,
#   263,
#   4,
#   2,
#   397,
#   12,
#   10,
#   36,
#   1684,
#   16,
#   157,
#   5,
#   3659,
#   16,
#   75,
#   131],
#  [93,
#   18,
#   157,
#   5,
#   263,
#   4,
#   2,
#   397,
#   12,
#   10,
#   36,
#   1684,
#   16,
#   157,
#   5,
#   3659,
#   16,
#   75,
#   131],
#  [93,
#   18,
#   157,
#   5,
#   263,
#   4,
#   2,
#   397,
#   12,
#   10,
#   36,
#   1684,
#   16,
#   157,
#   5,
#   3659,
#   16,
#   75,
#   131],
#  [93],
#  [18, 157, 5, 263, 4, 2, 397, 12, 10, 36, 1684, 16, 157, 5, 3659, 16, 75, 131],
#  [18],
#  [157, 5, 263, 4, 2, 397, 12, 10, 36, 1684, 16, 157, 5, 3659, 16, 75, 131],
#  [157],
#  [5, 263, 4, 2, 397, 12, 10, 36, 1684, 16, 157, 5, 3659, 16, 75, 131],
#  [263, 4, 2, 397, 12, 10, 36, 1684, 16, 157, 5, 3659, 16, 75, 131],
#  [263],
#  [4, 2, 397, 12, 10, 36, 1684, 16, 157, 5, 3659, 16, 75, 131],
#  [2, 397, 12, 10, 36, 1684, 16, 157, 5, 3659, 16, 75, 131],
#  [2, 397, 12],
#  [397, 12],
#  [397],
#  [10, 36, 1684, 16, 157, 5, 3659, 16, 75, 131],
#  [36, 1684, 16, 157, 5, 3659, 16, 75, 131],
#  [36],
#  [1684, 16, 157, 5, 3659, 16, 75, 131],
#  [1684],
#  [16, 157, 5, 3659, 16, 75, 131],
#  [157, 5, 3659, 16, 75, 131],
#  [5, 3659, 16, 75, 131],
#  [3659, 16, 75, 131],
#  [3659],
#  [16, 75, 131],
#  [75, 131],
#  [75],
#  [131],
#  [1, 40, 3, 1693, 37, 67],
#  [1, 40, 3, 1693],
#  [40, 3, 1693],
#  [40, 3],
#  [40],
#  [1693],
#  [37, 67],
#  [37, 67],
#  [37],
#  [67],
#  [1265, 20, 108, 51, 1, 292, 4, 8473, 2173, 2063, 1001],
#  [1265, 20],
#  [1265, 20],
#  [1265],
#  [],
#  [108, 51, 1, 292, 4, 8473, 2173, 2063, 1001],
#  [108, 51, 1, 292, 4, 8473, 2173, 2063, 1001],
#  [108],
#  [51, 1, 292, 4, 8473, 2173, 2063, 1001],
#  [1, 292, 4, 8473, 2173, 2063, 1001],
#  [1, 292],
#  [292],
#  [4, 8473, 2173, 2063, 1001],
#  [8473, 2173, 2063, 1001],
#  [8473, 2173],
#  [8473, 2173],
#  [8473],
#  [2173],
#  [2063, 1001],
#  [2063],
#  [1001],
#  [1, 12, 8, 57, 2, 626, 111, 536],
#  [1, 12, 8, 57, 2, 626, 111, 536],
#  [8, 57, 2, 626, 111, 536],
#  [8, 57, 2, 626, 111, 536],
#  [8, 57],
#  [57],
#  [2, 626, 111, 536],
#  [626, 111, 536],
#  [626, 111],
#  [626],
#  [111],
#  [536],
#  [16,
#   11,
#   7,
#   448,
#   5,
#   2260,
#   750,
#   8,
#   1,
#   259,
#   2,
#   65,
#   1297,
#   2578,
#   9,
#   2,
#   66,
#   8,
#   5,
#   2260,
#   1638,
#   2,
#   681,
#   60,
#   5936,
#   1604],
#  [16, 11, 7, 448, 5, 2260, 750],
#  [16, 11, 7, 448],
#  [16, 11, 7],
#  [11, 7],
#  [448],
#  [5, 2260, 750],
#  [2260, 750],
#  [2260],
#  [750],
#  [8,
#   1,
#   259,
#   2,
#   65,
#   1297,
#   2578,
#   9,
#   2,
#   66,
#   8,
#   5,
#   2260,
#   1638,
#   2,
#   681,
#   60,
#   5936,
#   1604],
#  [8,
#   1,
#   259,
#   2,
#   65,
#   1297,
#   2578,
#   9,
#   2,
#   66,
#   8,
#   5,
#   2260,
#   1638,
#   2,
#   681,
#   60,
#   5936,
#   1604],
#  [1,
#   259,
#   2,
#   65,
#   1297,
#   2578,
#   9,
#   2,
#   66,
#   8,
#   5,
#   2260,
#   1638,
#   2,
#   681,
#   60,
#   5936,
#   1604],
#  [1, 259],
#  [2, 65, 1297, 2578, 9, 2, 66, 8, 5, 2260, 1638, 2, 681, 60, 5936, 1604],
#  [65, 1297, 2578, 9, 2, 66, 8, 5, 2260, 1638, 2, 681, 60, 5936, 1604],
#  [1297, 2578, 9, 2, 66, 8, 5, 2260, 1638, 2, 681, 60, 5936, 1604],
#  [1297, 2578, 9, 2, 66],
#  [1297, 2578],
#  [1297, 2578],
#  [],
#  [9, 2, 66],
#  [2, 66],
#  [66],
#  [],
#  [66],
#  [8, 5, 2260, 1638, 2, 681, 60, 5936, 1604],
#  [5, 2260, 1638, 2, 681, 60, 5936, 1604],
#  [2260, 1638, 2, 681, 60, 5936, 1604],
#  [2260, 1638],
#  [2260, 1638],
#  [1638],
#  [],
#  [2, 681, 60, 5936, 1604],
#  [681, 60, 5936, 1604],
#  [681, 60, 5936],
#  [681],
#  [60, 5936],
#  [],
#  [60, 5936],
#  [60, 5936],
#  [60],
#  [5936],
#  [1604],
#  [2,
#   806,
#   4,
#   380,
#   158,
#   4,
#   96,
#   50,
#   89,
#   23,
#   22,
#   2754,
#   5,
#   1,
#   9001,
#   38,
#   8926,
#   32,
#   538,
#   1206,
#   2383,
#   6727,
#   8,
#   15,
#   5062,
#   395,
#   13,
#   2,
#   422,
#   5079,
#   2,
#   1861,
#   1356],
#  [2,
#   806,
#   4,
#   380,
#   158,
#   4,
#   96,
#   50,
#   89,
#   23,
#   22,
#   2754,
#   5,
#   1,
#   9001,
#   38,
#   8926,
#   32,
#   538,
#   1206,
#   2383,
#   6727,
#   8,
#   15,
#   5062,
#   395,
#   13,
#   2,
#   422,
#   5079,
#   2,
#   1861,
#   1356],
#  [2,
#   806,
#   4,
#   380,
#   158,
#   4,
#   96,
#   50,
#   89,
#   23,
#   22,
#   2754,
#   5,
#   1,
#   9001,
#   38,
#   8926,
#   32,
#   538],
#  [2,
#   806,
#   4,
#   380,
#   158,
#   4,
#   96,
#   50,
#   89,
#   23,
#   22,
#   2754,
#   5,
#   1,
#   9001,
#   38,
#   8926,
#   32,
#   538],
#  [2, 806, 4, 380, 158, 4, 96, 50, 89, 23, 22, 2754, 5, 1, 9001],
#  [2, 806],
#  [806],
#  [806],
#  [],
#  [4, 380, 158, 4, 96, 50, 89, 23, 22, 2754, 5, 1, 9001],
#  [380, 158, 4, 96, 50, 89, 23, 22, 2754, 5, 1, 9001],
#  [380],
#  [158, 4, 96, 50, 89, 23, 22, 2754, 5, 1, 9001],
#  [158, 4, 96],
#  [158],
#  [4, 96],
#  [96],
#  [50, 89, 23, 22, 2754, 5, 1, 9001],
#  [50],
#  [89, 23, 22, 2754, 5, 1, 9001],
#  [89, 23, 22],
#  [89],
#  [2754, 5, 1, 9001],
#  [2754],
#  [5, 1, 9001],
#  [1, 9001],
#  [9001],
#  [9001],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [38, 8926, 32, 538],
#  [38],
#  [8926, 32, 538],
#  [8926],
#  [32, 538],
#  [538],
#  [1206, 2383, 6727, 8, 15, 5062, 395, 13, 2, 422, 5079, 2, 1861, 1356],
#  [1206, 2383, 6727],
#  [1206],
#  [2383, 6727],
#  [2383],
#  [6727],
#  [8, 15, 5062, 395, 13, 2, 422, 5079, 2, 1861, 1356],
#  [15, 5062, 395, 13, 2, 422, 5079, 2, 1861, 1356],
#  [15, 5062, 395],
#  [5062, 395],
#  [],
#  [5062, 395],
#  [5062, 395],
#  [],
#  [5062, 395],
#  [5062, 395],
#  [],
#  [5062, 395],
#  [5062],
#  [395],
#  [13, 2, 422, 5079, 2, 1861, 1356],
#  [13],
#  [2, 422, 5079, 2, 1861, 1356],
#  [2, 422, 5079, 2, 1861],
#  [2, 422, 5079],
#  [422, 5079],
#  [422],
#  [5079],
#  [2, 1861],
#  [1861],
#  [1356],
#  [17, 89, 23, 22, 38, 5, 246, 30, 230, 5, 1998, 1, 11, 7, 1741, 4, 48, 3, 379],
#  [89, 23, 22, 38, 5, 246, 30, 230, 5, 1998, 1, 11, 7, 1741, 4, 48, 3, 379],
#  [89, 23, 22, 38, 5, 246, 30, 230, 5, 1998, 1, 11, 7, 1741, 4, 48, 3, 379],
#  [38, 5, 246, 30, 230, 5, 1998, 1, 11, 7, 1741, 4, 48, 3, 379],
#  [38, 5, 246, 30, 230],
#  [5, 246, 30, 230],
#  [246, 30, 230],
#  [246],
#  [30, 230],
#  [230],
#  [5, 1998, 1, 11, 7, 1741, 4, 48, 3, 379],
#  [1998, 1, 11, 7, 1741, 4, 48, 3, 379],
#  [1998],
#  [1, 11, 7, 1741, 4, 48, 3, 379],
#  [1, 11, 7, 1741],
#  [1, 11, 7],
#  [1741],
#  [],
#  [1741],
#  [4, 48, 3, 379],
#  [48, 3, 379],
#  [48, 3],
#  [48],
#  [379],
#  [1294,
#   6,
#   257,
#   1610,
#   3,
#   10,
#   686,
#   558,
#   166,
#   5260,
#   13,
#   6858,
#   7,
#   204,
#   2,
#   67,
#   2,
#   13,
#   4239,
#   751,
#   347],
#  [1294],
#  [6,
#   257,
#   1610,
#   3,
#   10,
#   686,
#   558,
#   166,
#   5260,
#   13,
#   6858,
#   7,
#   204,
#   2,
#   67,
#   2,
#   13,
#   4239,
#   751,
#   347],
#  [6,
#   257,
#   1610,
#   3,
#   10,
#   686,
#   558,
#   166,
#   5260,
#   13,
#   6858,
#   7,
#   204,
#   2,
#   67,
#   2,
#   13,
#   4239,
#   751,
#   347],
#  [257,
#   1610,
#   3,
#   10,
#   686,
#   558,
#   166,
#   5260,
#   13,
#   6858,
#   7,
#   204,
#   2,
#   67,
#   2,
#   13,
#   4239,
#   751,
#   347],
#  [257,
#   1610,
#   3,
#   10,
#   686,
#   558,
#   166,
#   5260,
#   13,
#   6858,
#   7,
#   204,
#   2,
#   67,
#   2,
#   13,
#   4239,
#   751,
#   347],
#  [257],
#  [1610,
#   3,
#   10,
#   686,
#   558,
#   166,
#   5260,
#   13,
#   6858,
#   7,
#   204,
#   2,
#   67,
#   2,
#   13,
#   4239,
#   751,
#   347],
#  [1610, 3],
#  [1610],
#  [10, 686, 558, 166, 5260, 13, 6858, 7, 204, 2, 67, 2, 13, 4239, 751, 347],
#  [10, 686, 558],
#  [686, 558],
#  [686],
#  [558],
#  [166, 5260, 13, 6858, 7, 204, 2, 67, 2, 13, 4239, 751, 347],
#  [166],
#  [5260, 13, 6858, 7, 204, 2, 67, 2, 13, 4239, 751, 347],
#  [5260],
#  [13, 6858, 7, 204, 2, 67, 2, 13, 4239, 751, 347],
#  [13, 6858, 7, 204, 2, 67, 2],
#  [13, 6858, 7, 204],
#  [6858, 7, 204],
#  [6858, 7],
#  [6858],
#  [204],
#  [2, 67, 2],
#  [67, 2],
#  [13, 4239, 751, 347],
#  [4239, 751, 347],
#  [4239],
#  [751, 347],
#  [751],
#  [347],
#  [1456,
#   783,
#   2363,
#   5,
#   1,
#   215,
#   4,
#   4653,
#   2,
#   1411,
#   273,
#   1,
#   11,
#   815,
#   2,
#   333,
#   1935,
#   4,
#   2016,
#   3,
#   169],
#  [1456, 783, 2363, 5, 1, 215, 4, 4653, 2, 1411, 273],
#  [1456],
#  [783, 2363, 5, 1, 215, 4, 4653, 2, 1411, 273],
#  [783],
#  [2363, 5, 1, 215, 4, 4653, 2, 1411, 273],
#  [2363],
#  [5, 1, 215, 4, 4653, 2, 1411, 273],
#  [1, 215, 4, 4653, 2, 1411, 273],
#  [1, 215],
#  [215],
#  [4, 4653, 2, 1411, 273],
#  [4653, 2, 1411, 273],
#  [4653],
#  [2, 1411, 273],
#  [1411, 273],
#  [1411],
#  [273],
#  [1, 11, 815, 2, 333, 1935, 4, 2016, 3, 169],
#  [1, 11, 815, 2, 333, 1935, 4, 2016, 3, 169],
#  [815, 2, 333, 1935, 4, 2016, 3, 169],
#  [815, 2, 333, 1935, 4, 2016, 3, 169],
#  [815, 2, 333, 1935, 4, 2016, 3],
#  [815, 2, 333, 1935, 4, 2016],
#  [2, 333, 1935, 4, 2016],
#  [2, 333, 1935],
#  [333, 1935],
#  [333],
#  [1935],
#  [4, 2016],
#  [2016],
#  [169],
#  [15, 783, 56, 20, 847, 2996, 1327, 41, 4, 611, 40],
#  [15, 783, 56, 20, 847, 2996, 1327, 41, 4, 611],
#  [783, 56, 20, 847, 2996, 1327, 41, 4, 611],
#  [783, 56, 20, 847, 2996],
#  [783, 56],
#  [56],
#  [20, 847, 2996],
#  [20, 847, 2996],
#  [847, 2996],
#  [847],
#  [2996],
#  [2996],
#  [1327, 41, 4, 611],
#  [40],
#  [2,
#   1749,
#   696,
#   13,
#   2,
#   222,
#   3947,
#   368,
#   314,
#   2,
#   112,
#   7413,
#   24,
#   2,
#   257,
#   4,
#   2084,
#   2051,
#   3,
#   2,
#   524,
#   4119,
#   9,
#   4083,
#   241,
#   775,
#   10432,
#   11397],
#  [2, 1749, 696, 13, 2, 222, 3947, 368],
#  [2, 1749, 696],
#  [1749, 696],
#  [1749],
#  [696],
#  [13, 2, 222, 3947, 368],
#  [2, 222, 3947, 368],
#  [222, 3947, 368],
#  [222, 3947],
#  [368],
#  [314,
#   2,
#   112,
#   7413,
#   24,
#   2,
#   257,
#   4,
#   2084,
#   2051,
#   3,
#   2,
#   524,
#   4119,
#   9,
#   4083,
#   241,
#   775,
#   10432,
#   11397],
#  [314,
#   2,
#   112,
#   7413,
#   24,
#   2,
#   257,
#   4,
#   2084,
#   2051,
#   3,
#   2,
#   524,
#   4119,
#   9,
#   4083,
#   241,
#   775,
#   10432,
#   11397],
#  [314, 2, 112, 7413, 24, 2, 257, 4, 2084, 2051, 3, 2, 524, 4119],
#  [314, 2, 112, 7413],
#  [2, 112, 7413],
#  [112, 7413],
#  [7413],
#  [24, 2, 257, 4, 2084, 2051, 3, 2, 524, 4119],
#  [2, 257, 4, 2084, 2051, 3, 2, 524, 4119],
#  [2, 257],
#  [257],
#  [4, 2084, 2051, 3, 2, 524, 4119],
#  [2084, 2051, 3, 2, 524, 4119],
#  [2084, 2051, 3],
#  [2084, 2051],
#  [2084],
#  [2051],
#  [2, 524, 4119],
#  [524, 4119],
#  [4119],
#  [9, 4083, 241, 775, 10432, 11397],
#  [4083, 241, 775, 10432, 11397],
#  [241, 775, 10432, 11397],
#  [241],
#  [775, 10432, 11397],
#  [775],
#  [10432, 11397],
#  [10432],
#  [11397],
#  [],
#  [11397],
#  [2,
#   8390,
#   330,
#   2857,
#   10,
#   60,
#   150,
#   496,
#   71,
#   701,
#   5,
#   288,
#   4,
#   9173,
#   9,
#   1,
#   454,
#   3,
#   6,
#   6699,
#   195,
#   12010],
#  [2, 8390, 330],
#  [8390, 330],
#  [8390],
#  [330],
#  [2857,
#   10,
#   60,
#   150,
#   496,
#   71,
#   701,
#   5,
#   288,
#   4,
#   9173,
#   9,
#   1,
#   454,
#   3,
#   6,
#   6699,
#   195,
#   12010],
#  [2857,
#   10,
#   60,
#   150,
#   496,
#   71,
#   701,
#   5,
#   288,
#   4,
#   9173,
#   9,
#   1,
#   454,
#   3,
#   6,
#   6699,
#   195,
#   12010],
#  [2857],
#  [10,
#   60,
#   150,
#   496,
#   71,
#   701,
#   5,
#   288,
#   4,
#   9173,
#   9,
#   1,
#   454,
#   3,
#   6,
#   6699,
#   195,
#   12010],
#  [60, 150, 496, 71, 701, 5, 288, 4, 9173, 9, 1, 454, 3, 6, 6699, 195, 12010],
#  [60, 150, 496, 71, 701, 5, 288, 4, 9173, 9, 1, 454, 3, 6, 6699, 195, 12010],
#  [60, 150, 496],
#  [150, 496],
#  [150],
#  [496],
#  [71, 701, 5, 288, 4, 9173, 9, 1, 454, 3, 6, 6699, 195, 12010],
#  [71, 701, 5, 288, 4, 9173, 9, 1, 454, 3, 6, 6699, 195, 12010],
#  [71],
#  [701, 5, 288, 4, 9173, 9, 1, 454, 3, 6, 6699, 195, 12010],
#  [701],
#  [5, 288, 4, 9173, 9, 1, 454, 3, 6, 6699, 195, 12010],
#  [288, 4, 9173, 9, 1, 454, 3, 6, 6699, 195, 12010],
#  [288],
#  [4, 9173, 9, 1, 454, 3, 6, 6699, 195, 12010],
#  [9173, 9, 1, 454, 3, 6, 6699, 195, 12010],
#  [9173, 9, 1, 454, 3],
#  [9173, 9, 1, 454],
#  [9173],
#  [9, 1, 454],
#  [1, 454],
#  [454],
#  [6, 6699, 195, 12010],
#  [6, 6699, 195],
#  [6, 6699, 195],
#  [6699, 195],
#  [6699],
#  [195],
#  [12010],
#  [12010],
#  [],
#  [60,
#   49,
#   567,
#   197,
#   56,
#   55,
#   97,
#   52,
#   34,
#   702,
#   55,
#   97,
#   52,
#   316,
#   6,
#   93,
#   18,
#   725,
#   470,
#   5,
#   2132,
#   1,
#   6,
#   7,
#   345,
#   5,
#   10110,
#   29,
#   1,
#   3273,
#   1516],
#  [60,
#   49,
#   567,
#   197,
#   56,
#   55,
#   97,
#   52,
#   34,
#   702,
#   55,
#   97,
#   52,
#   316,
#   6,
#   93,
#   18,
#   725,
#   470,
#   5,
#   2132,
#   1],
#  [60, 49, 567, 197, 56, 55, 97, 52, 34, 702, 55, 97, 52],
#  [49, 567, 197, 56, 55, 97, 52, 34, 702, 55, 97, 52],
#  [49, 567],
#  [567],
#  [197, 56, 55, 97, 52, 34, 702, 55, 97, 52],
#  [197],
#  [56, 55, 97, 52, 34, 702, 55, 97, 52],
#  [56, 55, 97, 52, 34],
#  [56, 55, 97, 52],
#  [55, 97, 52],
#  [97, 52],
#  [702, 55, 97, 52],
#  [702],
#  [316, 6, 93, 18, 725, 470, 5, 2132, 1],
#  [316],
#  [6, 93, 18, 725, 470, 5, 2132, 1],
#  [93, 18, 725, 470, 5, 2132, 1],
#  [18, 725, 470, 5, 2132, 1],
#  [725, 470, 5, 2132, 1],
#  [725],
#  [470, 5, 2132, 1],
#  [470],
#  [5, 2132, 1],
#  [2132, 1],
#  [2132],
#  [1],
#  [],
#  [],
#  [],
#  [6, 7, 345, 5, 10110, 29, 1, 3273, 1516],
#  [7, 345, 5, 10110, 29, 1, 3273, 1516],
#  [7, 345, 5, 10110, 29, 1, 3273, 1516],
#  [345, 5, 10110, 29, 1, 3273, 1516],
#  [345],
#  [5, 10110, 29, 1, 3273, 1516],
#  [10110, 29, 1, 3273, 1516],
#  [10110],
#  [29, 1, 3273, 1516],
#  [1, 3273, 1516],
#  [3273, 1516],
#  [3273],
#  [1516],
#  [4132,
#   29,
#   33,
#   102,
#   1902,
#   3,
#   274,
#   1060,
#   10,
#   16,
#   704,
#   141,
#   79,
#   1110,
#   4194,
#   4195],
#  [4132,
#   29,
#   33,
#   102,
#   1902,
#   3,
#   274,
#   1060,
#   10,
#   16,
#   704,
#   141,
#   79,
#   1110,
#   4194,
#   4195],
#  [4132],
#  [29, 33, 102, 1902, 3, 274, 1060, 10, 16, 704, 141, 79, 1110, 4194, 4195],
#  [33, 102, 1902, 3, 274, 1060, 10, 16, 704, 141, 79, 1110, 4194, 4195],
#  [33, 102, 1902, 3, 274, 1060],
#  [33, 102],
#  [33],
#  [102],
#  [1902, 3, 274, 1060],
#  [1902],
#  [3, 274, 1060],
#  [274, 1060],
#  [274],
#  [1060],
#  [10, 16, 704, 141, 79, 1110, 4194, 4195],
#  [16, 704, 141, 79, 1110, 4194, 4195],
#  [16, 704, 141],
#  [704, 141],
#  [704],
#  [79, 1110, 4194, 4195],
#  [79],
#  [1110, 4194, 4195],
#  [1110],
#  [4194, 4195],
#  [4194],
#  [4195],
#  [504, 6, 323, 2745, 7, 5937, 8, 27, 2, 6043, 300, 6, 8, 2, 633, 2, 21],
#  [504, 6, 323],
#  [504],
#  [6, 323],
#  [323],
#  [2745, 7, 5937, 8, 27, 2, 6043, 300, 6, 8, 2, 633, 2, 21],
#  [2745, 7, 5937, 8, 27, 2, 6043, 300, 6, 8, 2, 633, 2, 21],
#  [2745, 7, 5937],
#  [2745, 7],
#  [2745],
#  [5937],
#  [8, 27, 2, 6043, 300, 6, 8, 2, 633, 2, 21],
#  [8, 27, 2, 6043, 300, 6, 8, 2, 633, 2, 21],
#  [8, 27, 2, 6043],
#  [8, 27, 2, 6043],
#  [8, 27],
#  [2, 6043],
#  [6043],
#  [300, 6, 8, 2, 633, 2, 21],
#  [300],
#  [6, 8, 2, 633, 2, 21],
#  [8, 2, 633, 2, 21],
#  [2, 633, 2, 21],
#  [633, 2, 21],
#  [633],
#  [2, 21],
#  [21],
#  [10,
#   12241,
#   45,
#   71,
#   4,
#   1,
#   620,
#   3,
#   4270,
#   9363,
#   7,
#   4,
#   3105,
#   43,
#   1,
#   11,
#   464,
#   504,
#   73,
#   12074],
#  [12241,
#   45,
#   71,
#   4,
#   1,
#   620,
#   3,
#   4270,
#   9363,
#   7,
#   4,
#   3105,
#   43,
#   1,
#   11,
#   464,
#   504,
#   73,
#   12074],
#  [12241,
#   45,
#   71,
#   4,
#   1,
#   620,
#   3,
#   4270,
#   9363,
#   7,
#   4,
#   3105,
#   43,
#   1,
#   11,
#   464,
#   504,
#   73,
#   12074],
#  [12241, 45, 71, 4, 1, 620, 3, 4270, 9363, 7, 4, 3105],
#  [12241, 45, 71, 4, 1, 620, 3, 4270, 9363, 7, 4, 3105],
#  [12241],
#  [45, 71, 4, 1, 620, 3, 4270, 9363, 7, 4, 3105],
#  [45, 71, 4, 1, 620, 3, 4270, 9363, 7],
#  [45, 71, 4, 1, 620, 3, 4270, 9363, 7],
#  [45, 71],
#  [4, 1, 620, 3, 4270, 9363, 7],
#  [4, 1, 620, 3, 4270, 9363],
#  [1, 620, 3, 4270, 9363],
#  [1, 620, 3],
#  [1, 620],
#  [620],
#  [4270, 9363],
#  [],
#  [4270, 9363],
#  [4270],
#  [9363],
#  [],
#  [9363],
#  ...]

# %%
X_test = sequence.pad_sequences(X_test, maxlen = max_words)
X_test
# Out:
# array([[   0,    0,    0, ...,  719,  789,  347],
#        [   0,    0,    0, ...,  719,  789,  347],
#        [   0,    0,    0, ...,    0,    0,   15],
#        ...,
#        [   0,    0,    0, ...,    2,  127, 8227],
#        [   0,    0,    0, ...,    2,  127, 8227],
#        [   0,    0,    0, ...,    0,  360, 1802]])

# %%
pred = model1.predict_classes(X_test, verbose = 1)
# Out:
# 66292/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
sub = pd.read_csv('sampleSubmission.csv', sep = ",")
sub.Sentiment = pred
sub.to_csv('Result.csv', index = False)
